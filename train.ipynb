# %% [markdown]
# ## Setup

# %%
#Download Dataset
#!wget http://weegee.vision.ucmerced.edu/datasets/UCMerced_LandUse.zip
# !unzip -o -q UCMerced_LandUse.zip
# !rm UCMerced_LandUse.zip
# !mv UCMerced_LandUse data

# %%
from src.ds import UCMerced, HQLQ
from src.util import random_split_ratio, psnr
from src.srresnet import SRResNet
from torch.utils.data import DataLoader
import torch
from torchvision import transforms
from PIL import Image
from tqdm import tqdm
import numpy as np
from collections import defaultdict
import random

#fix random seeds
seed=31415
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# %%
#Data
dataset = UCMerced("data")
#image augmentation transformations for train, validation and test
augments = [
    [
        transforms.RandomCrop((96, 96)),
        transforms.RandomVerticalFlip(),
        transforms.RandomHorizontalFlip(),
    ],
    [],
    [],
]

scaling_factor = 4
valratio, testratio = 0.1, 0.1
trainds, valds, testds = (
    HQLQ(ds, aug, scalingfactor=scaling_factor)
    for ds, aug in zip(random_split_ratio(dataset, valratio, testratio), augments)
)

# %% [markdown]
# ## Parameters

# %%
# Model parameters -- taken from https://github.com/sgrvinod/a-PyTorch-Tutorial-to-Super-Resolution
large_kernel_size = 9  # kernel size of the first and last convolutions which transform the inputs and outputs
small_kernel_size = 3  # kernel size of all convolutions in-between, i.e. those in the residual and subpixel convolutional blocks
n_channels = 64  # number of channels in-between, i.e. the input and output channels for the residual and subpixel convolutional blocks
n_blocks = 16  # number of residual blocks

# Learning parameters
batch_size = 64  # batch size
try:
    start_epoch = epoch  # start at old epoch if already defined from earlier execution
except:
    start_epoch = 0
iterations = 5e4  # number of training iterations
workers = 4  # number of workers for loading data in the DataLoader
lr = 1e-4  # learning rate
device = "cuda" if torch.cuda.is_available() else "cpu"


train_loader = DataLoader(trainds, batch_size=batch_size, shuffle=True, num_workers=workers, pin_memory=True)
val_loader = DataLoader(valds, batch_size=batch_size, shuffle=True, num_workers=workers, pin_memory=True)

# %%
import time


def train(train_loader, model, criterion, optimizer):
    """
    train one epoch
    :param train_loader: DataLoader
    :param model: model
    :param criterion: loss function
    :param optimizer: optimizer
    returns (losses,data_time,batch_time)
    """
    model.train()
    start = time.time()
    data_time = 0
    run_time = 0
    losses = []
    for i, (lq, hq) in enumerate(train_loader):
        # Move to device
        lq = lq.to(device)
        hq = hq.to(device)

        data_time += time.time() - start

        # Forward
        sr = model(lq)

        # Loss
        loss = criterion(sr, hq)

        # Backward
        optimizer.zero_grad()
        loss.backward()

        # Update model
        optimizer.step()

        losses.append(loss.item())
        run_time += time.time() - start
        start = time.time()

    del lq, hq, sr
    return (losses, data_time, run_time)

# %%
def validate(val_loader,model,criterion):
    """
    validate one epoch
    :param tval_loader: DataLoader 
    :param model: model
    :param criterion: loss function
    returns loss and psnr
    """

    with torch.no_grad():
        model.eval()
        avg_loss,avg_psnr = 0., 0.
        
        for lq, hq in val_loader:
            lq, hq = lq.to(device), hq.to(device)
            
            #forward
            sr = model(lq)
            
            #criteria
            avg_loss += criterion(sr, hq).item() / len(val_loader)
            avg_psnr += psnr(hq,sr) / len(val_loader)
            
        return (avg_loss,avg_psnr)

# %%
#initialize model without overwriting
try: 
    model
    print('model not changed!')
except:
    model = SRResNet(large_kernel_size=large_kernel_size, small_kernel_size=small_kernel_size,
                  n_channels=n_channels, n_blocks=n_blocks, scaling_factor=scaling_factor)
 
    #load pretrained weights, extracted from checkpoint at https://drive.google.com/drive/folders/12OG-KawSFFs6Pah89V4a_Td-VcwMBE5i?usp=sharing
    model.load_state_dict(torch.load('weights/sgrvinod.zip'))
    
optimizer = torch.optim.Adam(params=filter(lambda p: p.requires_grad, model.parameters()),
                              lr=lr)
model = model.to(device)
criterion = torch.nn.MSELoss().to(device)

# %% [markdown]
# ## Train

# %%
#keep log for plot in the end
try:
    logs
except:
    logs=defaultdict(list)

epochs = int(iterations // len(train_loader) + 1)
for epoch in (range(start_epoch, epochs)):
    (train_losses,data_time,batch_time) = train(train_loader=train_loader, model=model, criterion=criterion, optimizer=optimizer)
    train_loss=np.mean(train_losses)
    logs['train'].append((epoch,train_loss))

    if epoch%2==0:
        (val_loss,val_psnr) = validate(val_loader=val_loader,model=model,criterion=criterion)
        logs['val'].append((epoch,val_loss,val_psnr))
        print(f"[{epoch}/{epochs}] -- Time: Data {data_time:.2f}s, Epoch {batch_time:.2f}s -- TrainLoss {train_loss:.4f} -- ValLoss {val_loss:.4f} -- ValPSNR {val_psnr:.4f}")
    else:
        print(f"[{epoch}/{epochs}] -- Time: Data {data_time:.2f}s, Epoch {batch_time:.2f}s -- TrainLoss {train_loss:.4f}")
# Out:
# [0/1852] -- Time: Data 0.46s, Epoch 4.68s -- TrainLoss 0.0151 -- ValLoss 0.0128 -- ValPSNR 18.9427
# [1/1852] -- Time: Data 0.41s, Epoch 4.26s -- TrainLoss 0.0126
# [2/1852] -- Time: Data 0.41s, Epoch 4.29s -- TrainLoss 0.0125 -- ValLoss 0.0112 -- ValPSNR 19.5784
# [3/1852] -- Time: Data 0.39s, Epoch 4.34s -- TrainLoss 0.0121
# [4/1852] -- Time: Data 0.41s, Epoch 4.27s -- TrainLoss 0.0123 -- ValLoss 0.0120 -- ValPSNR 19.2520
# [5/1852] -- Time: Data 0.41s, Epoch 4.36s -- TrainLoss 0.0122
# [6/1852] -- Time: Data 0.40s, Epoch 4.30s -- TrainLoss 0.0118 -- ValLoss 0.0124 -- ValPSNR 19.1384
# [7/1852] -- Time: Data 0.41s, Epoch 4.29s -- TrainLoss 0.0119
# [8/1852] -- Time: Data 0.39s, Epoch 4.27s -- TrainLoss 0.0119 -- ValLoss 0.0115 -- ValPSNR 19.4391
# [9/1852] -- Time: Data 0.39s, Epoch 4.30s -- TrainLoss 0.0119
# [10/1852] -- Time: Data 0.39s, Epoch 4.38s -- TrainLoss 0.0117 -- ValLoss 0.0107 -- ValPSNR 19.8052
# [11/1852] -- Time: Data 0.38s, Epoch 4.26s -- TrainLoss 0.0118
# [12/1852] -- Time: Data 0.39s, Epoch 4.27s -- TrainLoss 0.0119 -- ValLoss 0.0103 -- ValPSNR 20.0614
# [13/1852] -- Time: Data 0.47s, Epoch 4.46s -- TrainLoss 0.0118
# [14/1852] -- Time: Data 0.41s, Epoch 4.31s -- TrainLoss 0.0119 -- ValLoss 0.0109 -- ValPSNR 19.6465
# [15/1852] -- Time: Data 0.40s, Epoch 4.34s -- TrainLoss 0.0121
# [16/1852] -- Time: Data 0.40s, Epoch 4.44s -- TrainLoss 0.0116 -- ValLoss 0.0113 -- ValPSNR 19.5259
# [17/1852] -- Time: Data 0.40s, Epoch 4.27s -- TrainLoss 0.0116
# [18/1852] -- Time: Data 0.38s, Epoch 4.35s -- TrainLoss 0.0117 -- ValLoss 0.0106 -- ValPSNR 19.7917
# [19/1852] -- Time: Data 0.39s, Epoch 4.40s -- TrainLoss 0.0115
# [20/1852] -- Time: Data 0.38s, Epoch 4.41s -- TrainLoss 0.0115 -- ValLoss 0.0108 -- ValPSNR 19.7260
# [21/1852] -- Time: Data 0.38s, Epoch 4.29s -- TrainLoss 0.0115
# [22/1852] -- Time: Data 0.40s, Epoch 4.36s -- TrainLoss 0.0117 -- ValLoss 0.0104 -- ValPSNR 20.0339
# [23/1852] -- Time: Data 0.40s, Epoch 4.32s -- TrainLoss 0.0117
# [24/1852] -- Time: Data 0.39s, Epoch 4.37s -- TrainLoss 0.0117 -- ValLoss 0.0106 -- ValPSNR 19.8141
# [25/1852] -- Time: Data 0.41s, Epoch 4.33s -- TrainLoss 0.0117
# [26/1852] -- Time: Data 0.41s, Epoch 4.42s -- TrainLoss 0.0118 -- ValLoss 0.0114 -- ValPSNR 19.4997
# [27/1852] -- Time: Data 0.44s, Epoch 4.41s -- TrainLoss 0.0114
# [28/1852] -- Time: Data 0.43s, Epoch 4.34s -- TrainLoss 0.0115 -- ValLoss 0.0110 -- ValPSNR 19.6358
# [29/1852] -- Time: Data 0.45s, Epoch 4.34s -- TrainLoss 0.0116
# [30/1852] -- Time: Data 0.42s, Epoch 4.35s -- TrainLoss 0.0115 -- ValLoss 0.0112 -- ValPSNR 19.6425
# [31/1852] -- Time: Data 0.40s, Epoch 4.30s -- TrainLoss 0.0118
# [32/1852] -- Time: Data 0.41s, Epoch 4.35s -- TrainLoss 0.0116 -- ValLoss 0.0124 -- ValPSNR 19.2423
# [33/1852] -- Time: Data 0.45s, Epoch 4.34s -- TrainLoss 0.0116
# [34/1852] -- Time: Data 0.39s, Epoch 4.36s -- TrainLoss 0.0117 -- ValLoss 0.0104 -- ValPSNR 19.9482
# [35/1852] -- Time: Data 0.39s, Epoch 4.30s -- TrainLoss 0.0113
# [36/1852] -- Time: Data 0.41s, Epoch 4.31s -- TrainLoss 0.0116 -- ValLoss 0.0111 -- ValPSNR 19.5502
# [37/1852] -- Time: Data 0.39s, Epoch 4.31s -- TrainLoss 0.0113
# [38/1852] -- Time: Data 0.40s, Epoch 4.30s -- TrainLoss 0.0112 -- ValLoss 0.0113 -- ValPSNR 19.4952
# [39/1852] -- Time: Data 0.45s, Epoch 4.41s -- TrainLoss 0.0117
# [40/1852] -- Time: Data 0.42s, Epoch 4.34s -- TrainLoss 0.0116 -- ValLoss 0.0109 -- ValPSNR 19.6762
# [41/1852] -- Time: Data 0.41s, Epoch 4.41s -- TrainLoss 0.0114
# [42/1852] -- Time: Data 0.39s, Epoch 4.36s -- TrainLoss 0.0117 -- ValLoss 0.0112 -- ValPSNR 19.5514
# [43/1852] -- Time: Data 0.41s, Epoch 4.49s -- TrainLoss 0.0115
# [44/1852] -- Time: Data 0.45s, Epoch 4.40s -- TrainLoss 0.0118 -- ValLoss 0.0109 -- ValPSNR 19.6583
# [45/1852] -- Time: Data 0.41s, Epoch 4.32s -- TrainLoss 0.0115
# [46/1852] -- Time: Data 0.37s, Epoch 4.29s -- TrainLoss 0.0115 -- ValLoss 0.0104 -- ValPSNR 19.9024
# [47/1852] -- Time: Data 0.40s, Epoch 4.34s -- TrainLoss 0.0111
# [48/1852] -- Time: Data 0.40s, Epoch 4.41s -- TrainLoss 0.0113 -- ValLoss 0.0106 -- ValPSNR 19.8182
# [49/1852] -- Time: Data 0.45s, Epoch 4.37s -- TrainLoss 0.0113
# [50/1852] -- Time: Data 0.41s, Epoch 4.39s -- TrainLoss 0.0115 -- ValLoss 0.0108 -- ValPSNR 19.6660
# [51/1852] -- Time: Data 0.40s, Epoch 4.30s -- TrainLoss 0.0112
# [52/1852] -- Time: Data 0.41s, Epoch 4.44s -- TrainLoss 0.0115 -- ValLoss 0.0110 -- ValPSNR 19.6138
# [53/1852] -- Time: Data 0.40s, Epoch 4.31s -- TrainLoss 0.0112
# [54/1852] -- Time: Data 0.39s, Epoch 4.33s -- TrainLoss 0.0112 -- ValLoss 0.0104 -- ValPSNR 19.8851
# [55/1852] -- Time: Data 0.40s, Epoch 4.35s -- TrainLoss 0.0113
# [56/1852] -- Time: Data 0.39s, Epoch 4.35s -- TrainLoss 0.0113 -- ValLoss 0.0113 -- ValPSNR 19.5127
# [57/1852] -- Time: Data 0.42s, Epoch 4.35s -- TrainLoss 0.0111
# [58/1852] -- Time: Data 0.40s, Epoch 4.35s -- TrainLoss 0.0111 -- ValLoss 0.0109 -- ValPSNR 19.7020
# [59/1852] -- Time: Data 0.40s, Epoch 4.32s -- TrainLoss 0.0115
# [60/1852] -- Time: Data 0.42s, Epoch 4.33s -- TrainLoss 0.0113 -- ValLoss 0.0103 -- ValPSNR 20.0151
# [61/1852] -- Time: Data 0.44s, Epoch 4.38s -- TrainLoss 0.0114
# [62/1852] -- Time: Data 0.39s, Epoch 4.34s -- TrainLoss 0.0113 -- ValLoss 0.0108 -- ValPSNR 19.6556
# [63/1852] -- Time: Data 0.42s, Epoch 4.42s -- TrainLoss 0.0113
# [64/1852] -- Time: Data 0.45s, Epoch 4.37s -- TrainLoss 0.0109 -- ValLoss 0.0100 -- ValPSNR 20.1395
# [65/1852] -- Time: Data 0.43s, Epoch 4.36s -- TrainLoss 0.0114
# [66/1852] -- Time: Data 0.41s, Epoch 4.34s -- TrainLoss 0.0116 -- ValLoss 0.0106 -- ValPSNR 19.8146
# [67/1852] -- Time: Data 0.47s, Epoch 4.59s -- TrainLoss 0.0112
# [68/1852] -- Time: Data 0.40s, Epoch 4.38s -- TrainLoss 0.0115 -- ValLoss 0.0103 -- ValPSNR 19.9457
# [69/1852] -- Time: Data 0.42s, Epoch 4.35s -- TrainLoss 0.0113
# [70/1852] -- Time: Data 0.40s, Epoch 4.44s -- TrainLoss 0.0112 -- ValLoss 0.0100 -- ValPSNR 20.1532
# [71/1852] -- Time: Data 0.45s, Epoch 4.56s -- TrainLoss 0.0112
# [72/1852] -- Time: Data 0.39s, Epoch 4.41s -- TrainLoss 0.0113 -- ValLoss 0.0110 -- ValPSNR 19.6423
# [73/1852] -- Time: Data 0.40s, Epoch 4.33s -- TrainLoss 0.0110
# [74/1852] -- Time: Data 0.39s, Epoch 4.29s -- TrainLoss 0.0114 -- ValLoss 0.0104 -- ValPSNR 19.8593
# [75/1852] -- Time: Data 0.44s, Epoch 4.37s -- TrainLoss 0.0110
# [76/1852] -- Time: Data 0.41s, Epoch 4.32s -- TrainLoss 0.0112 -- ValLoss 0.0100 -- ValPSNR 20.0769
# [77/1852] -- Time: Data 0.41s, Epoch 4.38s -- TrainLoss 0.0112
# [78/1852] -- Time: Data 0.42s, Epoch 4.44s -- TrainLoss 0.0114 -- ValLoss 0.0109 -- ValPSNR 19.6624
# [79/1852] -- Time: Data 0.38s, Epoch 4.39s -- TrainLoss 0.0115
# [80/1852] -- Time: Data 0.40s, Epoch 4.40s -- TrainLoss 0.0113 -- ValLoss 0.0104 -- ValPSNR 19.8527
# [81/1852] -- Time: Data 0.39s, Epoch 4.33s -- TrainLoss 0.0114
# [82/1852] -- Time: Data 0.39s, Epoch 4.32s -- TrainLoss 0.0111 -- ValLoss 0.0100 -- ValPSNR 20.1321
# [83/1852] -- Time: Data 0.43s, Epoch 4.36s -- TrainLoss 0.0109
# [84/1852] -- Time: Data 0.37s, Epoch 4.29s -- TrainLoss 0.0111 -- ValLoss 0.0108 -- ValPSNR 19.6752
# [85/1852] -- Time: Data 0.38s, Epoch 4.31s -- TrainLoss 0.0109
# [86/1852] -- Time: Data 0.39s, Epoch 4.31s -- TrainLoss 0.0115 -- ValLoss 0.0099 -- ValPSNR 20.2222
# [87/1852] -- Time: Data 0.42s, Epoch 4.33s -- TrainLoss 0.0113
# [88/1852] -- Time: Data 0.39s, Epoch 4.32s -- TrainLoss 0.0110 -- ValLoss 0.0107 -- ValPSNR 19.6957
# [89/1852] -- Time: Data 0.39s, Epoch 4.38s -- TrainLoss 0.0112
# [90/1852] -- Time: Data 0.39s, Epoch 4.32s -- TrainLoss 0.0112 -- ValLoss 0.0102 -- ValPSNR 19.9604
# [91/1852] -- Time: Data 0.41s, Epoch 4.33s -- TrainLoss 0.0110
# [92/1852] -- Time: Data 0.40s, Epoch 4.56s -- TrainLoss 0.0115 -- ValLoss 0.0110 -- ValPSNR 19.6806
# [93/1852] -- Time: Data 0.39s, Epoch 4.34s -- TrainLoss 0.0112
# [94/1852] -- Time: Data 0.40s, Epoch 4.31s -- TrainLoss 0.0110 -- ValLoss 0.0120 -- ValPSNR 19.3692
# [95/1852] -- Time: Data 0.41s, Epoch 4.42s -- TrainLoss 0.0110
# [96/1852] -- Time: Data 0.38s, Epoch 4.30s -- TrainLoss 0.0110 -- ValLoss 0.0101 -- ValPSNR 20.0368
# [97/1852] -- Time: Data 0.41s, Epoch 4.35s -- TrainLoss 0.0112
# [98/1852] -- Time: Data 0.41s, Epoch 4.43s -- TrainLoss 0.0113 -- ValLoss 0.0104 -- ValPSNR 19.9388
# [99/1852] -- Time: Data 0.41s, Epoch 4.41s -- TrainLoss 0.0111
# [100/1852] -- Time: Data 0.38s, Epoch 4.31s -- TrainLoss 0.0112 -- ValLoss 0.0113 -- ValPSNR 19.5363
# [101/1852] -- Time: Data 0.41s, Epoch 4.40s -- TrainLoss 0.0110
# [102/1852] -- Time: Data 0.39s, Epoch 4.39s -- TrainLoss 0.0109 -- ValLoss 0.0108 -- ValPSNR 19.6890
# [103/1852] -- Time: Data 0.42s, Epoch 4.43s -- TrainLoss 0.0109
# [104/1852] -- Time: Data 0.42s, Epoch 4.34s -- TrainLoss 0.0111 -- ValLoss 0.0101 -- ValPSNR 19.9999
# [105/1852] -- Time: Data 0.40s, Epoch 4.36s -- TrainLoss 0.0109
# [106/1852] -- Time: Data 0.38s, Epoch 4.31s -- TrainLoss 0.0110 -- ValLoss 0.0108 -- ValPSNR 19.6708
# [107/1852] -- Time: Data 0.41s, Epoch 4.32s -- TrainLoss 0.0111
# [108/1852] -- Time: Data 0.37s, Epoch 4.44s -- TrainLoss 0.0109 -- ValLoss 0.0109 -- ValPSNR 19.7204
# [109/1852] -- Time: Data 0.38s, Epoch 4.44s -- TrainLoss 0.0110
# [110/1852] -- Time: Data 0.41s, Epoch 4.33s -- TrainLoss 0.0113 -- ValLoss 0.0106 -- ValPSNR 19.7813
# [111/1852] -- Time: Data 0.43s, Epoch 4.35s -- TrainLoss 0.0112
# [112/1852] -- Time: Data 0.47s, Epoch 4.43s -- TrainLoss 0.0109 -- ValLoss 0.0107 -- ValPSNR 19.7553
# [113/1852] -- Time: Data 0.38s, Epoch 4.35s -- TrainLoss 0.0110
# [114/1852] -- Time: Data 0.41s, Epoch 4.45s -- TrainLoss 0.0112 -- ValLoss 0.0098 -- ValPSNR 20.2329
# [115/1852] -- Time: Data 0.41s, Epoch 4.33s -- TrainLoss 0.0110
# [116/1852] -- Time: Data 0.43s, Epoch 4.36s -- TrainLoss 0.0110 -- ValLoss 0.0112 -- ValPSNR 19.6868
# [117/1852] -- Time: Data 0.41s, Epoch 4.37s -- TrainLoss 0.0111
# [118/1852] -- Time: Data 0.39s, Epoch 4.37s -- TrainLoss 0.0110 -- ValLoss 0.0113 -- ValPSNR 19.6236
# [119/1852] -- Time: Data 0.41s, Epoch 4.36s -- TrainLoss 0.0111
# [120/1852] -- Time: Data 0.42s, Epoch 4.45s -- TrainLoss 0.0111 -- ValLoss 0.0105 -- ValPSNR 19.8593
# [121/1852] -- Time: Data 0.44s, Epoch 4.38s -- TrainLoss 0.0110
# [122/1852] -- Time: Data 0.39s, Epoch 4.33s -- TrainLoss 0.0112 -- ValLoss 0.0105 -- ValPSNR 19.7883
# [123/1852] -- Time: Data 0.39s, Epoch 4.28s -- TrainLoss 0.0110
# [124/1852] -- Time: Data 0.40s, Epoch 4.30s -- TrainLoss 0.0111 -- ValLoss 0.0101 -- ValPSNR 20.0831
# [125/1852] -- Time: Data 0.42s, Epoch 4.47s -- TrainLoss 0.0110
# [126/1852] -- Time: Data 0.40s, Epoch 4.33s -- TrainLoss 0.0111 -- ValLoss 0.0100 -- ValPSNR 20.1364
# [127/1852] -- Time: Data 0.41s, Epoch 4.36s -- TrainLoss 0.0112
# [128/1852] -- Time: Data 0.39s, Epoch 4.31s -- TrainLoss 0.0107 -- ValLoss 0.0101 -- ValPSNR 19.9924
# [129/1852] -- Time: Data 0.41s, Epoch 4.31s -- TrainLoss 0.0112
# [130/1852] -- Time: Data 0.40s, Epoch 4.46s -- TrainLoss 0.0110 -- ValLoss 0.0104 -- ValPSNR 19.8498
# [131/1852] -- Time: Data 0.42s, Epoch 4.33s -- TrainLoss 0.0110
# [132/1852] -- Time: Data 0.41s, Epoch 4.31s -- TrainLoss 0.0110 -- ValLoss 0.0098 -- ValPSNR 20.2513
# [133/1852] -- Time: Data 0.42s, Epoch 4.31s -- TrainLoss 0.0108
# [134/1852] -- Time: Data 0.43s, Epoch 4.32s -- TrainLoss 0.0109 -- ValLoss 0.0100 -- ValPSNR 20.0638
# [135/1852] -- Time: Data 0.41s, Epoch 4.50s -- TrainLoss 0.0110
# [136/1852] -- Time: Data 0.43s, Epoch 4.38s -- TrainLoss 0.0110 -- ValLoss 0.0106 -- ValPSNR 19.7815
# [137/1852] -- Time: Data 0.45s, Epoch 4.39s -- TrainLoss 0.0111
# [138/1852] -- Time: Data 0.39s, Epoch 4.29s -- TrainLoss 0.0107 -- ValLoss 0.0093 -- ValPSNR 20.7338
# [139/1852] -- Time: Data 0.37s, Epoch 4.33s -- TrainLoss 0.0111
# [140/1852] -- Time: Data 0.42s, Epoch 4.34s -- TrainLoss 0.0110 -- ValLoss 0.0109 -- ValPSNR 19.6720
# [141/1852] -- Time: Data 0.39s, Epoch 4.32s -- TrainLoss 0.0111
# [142/1852] -- Time: Data 0.41s, Epoch 4.43s -- TrainLoss 0.0112 -- ValLoss 0.0101 -- ValPSNR 20.0323
# [143/1852] -- Time: Data 0.39s, Epoch 4.31s -- TrainLoss 0.0112
# [144/1852] -- Time: Data 0.38s, Epoch 4.30s -- TrainLoss 0.0109 -- ValLoss 0.0105 -- ValPSNR 19.8086
# [145/1852] -- Time: Data 0.45s, Epoch 4.38s -- TrainLoss 0.0112
# [146/1852] -- Time: Data 0.42s, Epoch 4.38s -- TrainLoss 0.0109 -- ValLoss 0.0103 -- ValPSNR 19.9036
# [147/1852] -- Time: Data 0.43s, Epoch 4.36s -- TrainLoss 0.0113
# [148/1852] -- Time: Data 0.40s, Epoch 4.37s -- TrainLoss 0.0109 -- ValLoss 0.0107 -- ValPSNR 19.7538
# [149/1852] -- Time: Data 0.42s, Epoch 4.43s -- TrainLoss 0.0110
# [150/1852] -- Time: Data 0.42s, Epoch 4.38s -- TrainLoss 0.0110 -- ValLoss 0.0106 -- ValPSNR 19.8070
# [151/1852] -- Time: Data 0.43s, Epoch 4.36s -- TrainLoss 0.0109
# [152/1852] -- Time: Data 0.42s, Epoch 4.42s -- TrainLoss 0.0110 -- ValLoss 0.0110 -- ValPSNR 19.6185
# [153/1852] -- Time: Data 0.40s, Epoch 4.47s -- TrainLoss 0.0108
# [154/1852] -- Time: Data 0.41s, Epoch 4.38s -- TrainLoss 0.0109 -- ValLoss 0.0109 -- ValPSNR 19.7084
# [155/1852] -- Time: Data 0.44s, Epoch 4.40s -- TrainLoss 0.0111
# [156/1852] -- Time: Data 0.43s, Epoch 4.45s -- TrainLoss 0.0110 -- ValLoss 0.0104 -- ValPSNR 19.8692
# [157/1852] -- Time: Data 0.41s, Epoch 4.45s -- TrainLoss 0.0109
# [158/1852] -- Time: Data 0.40s, Epoch 4.40s -- TrainLoss 0.0110 -- ValLoss 0.0104 -- ValPSNR 19.9161
# [159/1852] -- Time: Data 0.42s, Epoch 4.36s -- TrainLoss 0.0108
# [160/1852] -- Time: Data 0.39s, Epoch 4.29s -- TrainLoss 0.0106 -- ValLoss 0.0102 -- ValPSNR 19.9394
# [161/1852] -- Time: Data 0.43s, Epoch 4.46s -- TrainLoss 0.0108
# [162/1852] -- Time: Data 0.39s, Epoch 4.41s -- TrainLoss 0.0111 -- ValLoss 0.0098 -- ValPSNR 20.1991
# [163/1852] -- Time: Data 0.40s, Epoch 4.35s -- TrainLoss 0.0110
# [164/1852] -- Time: Data 0.40s, Epoch 4.33s -- TrainLoss 0.0109 -- ValLoss 0.0114 -- ValPSNR 19.5302
# [165/1852] -- Time: Data 0.39s, Epoch 4.32s -- TrainLoss 0.0108
# [166/1852] -- Time: Data 0.39s, Epoch 4.31s -- TrainLoss 0.0110 -- ValLoss 0.0104 -- ValPSNR 19.8571
# [167/1852] -- Time: Data 0.42s, Epoch 4.40s -- TrainLoss 0.0109
# [168/1852] -- Time: Data 0.43s, Epoch 4.34s -- TrainLoss 0.0111 -- ValLoss 0.0109 -- ValPSNR 19.6752
# [169/1852] -- Time: Data 0.39s, Epoch 4.45s -- TrainLoss 0.0109
# [170/1852] -- Time: Data 0.40s, Epoch 4.32s -- TrainLoss 0.0109 -- ValLoss 0.0110 -- ValPSNR 19.6426
# [171/1852] -- Time: Data 0.37s, Epoch 4.34s -- TrainLoss 0.0108
# [172/1852] -- Time: Data 0.39s, Epoch 4.30s -- TrainLoss 0.0108 -- ValLoss 0.0103 -- ValPSNR 19.9264
# [173/1852] -- Time: Data 0.40s, Epoch 4.33s -- TrainLoss 0.0109
# [174/1852] -- Time: Data 0.41s, Epoch 4.37s -- TrainLoss 0.0110 -- ValLoss 0.0102 -- ValPSNR 19.9287
# [175/1852] -- Time: Data 0.44s, Epoch 4.38s -- TrainLoss 0.0110
# [176/1852] -- Time: Data 0.45s, Epoch 4.38s -- TrainLoss 0.0107 -- ValLoss 0.0109 -- ValPSNR 19.7939
# [177/1852] -- Time: Data 0.39s, Epoch 4.38s -- TrainLoss 0.0108
# [178/1852] -- Time: Data 0.39s, Epoch 4.31s -- TrainLoss 0.0107 -- ValLoss 0.0103 -- ValPSNR 19.8723
# [179/1852] -- Time: Data 0.46s, Epoch 4.40s -- TrainLoss 0.0108
# [180/1852] -- Time: Data 0.40s, Epoch 4.32s -- TrainLoss 0.0110 -- ValLoss 0.0108 -- ValPSNR 19.7567
# [181/1852] -- Time: Data 0.41s, Epoch 4.35s -- TrainLoss 0.0109
# [182/1852] -- Time: Data 0.41s, Epoch 4.34s -- TrainLoss 0.0109 -- ValLoss 0.0108 -- ValPSNR 19.6936
# [183/1852] -- Time: Data 0.43s, Epoch 4.36s -- TrainLoss 0.0109
# [184/1852] -- Time: Data 0.42s, Epoch 4.37s -- TrainLoss 0.0109 -- ValLoss 0.0101 -- ValPSNR 20.0338
# [185/1852] -- Time: Data 0.41s, Epoch 4.35s -- TrainLoss 0.0107
# [186/1852] -- Time: Data 0.41s, Epoch 4.35s -- TrainLoss 0.0109 -- ValLoss 0.0103 -- ValPSNR 19.8850
# [187/1852] -- Time: Data 0.44s, Epoch 4.38s -- TrainLoss 0.0109
# [188/1852] -- Time: Data 0.40s, Epoch 4.32s -- TrainLoss 0.0110 -- ValLoss 0.0103 -- ValPSNR 19.9295
# [189/1852] -- Time: Data 0.41s, Epoch 4.33s -- TrainLoss 0.0109
# [190/1852] -- Time: Data 0.46s, Epoch 4.48s -- TrainLoss 0.0108 -- ValLoss 0.0093 -- ValPSNR 20.8287
# [191/1852] -- Time: Data 0.39s, Epoch 4.33s -- TrainLoss 0.0108
# [192/1852] -- Time: Data 0.40s, Epoch 4.33s -- TrainLoss 0.0109 -- ValLoss 0.0098 -- ValPSNR 20.1898
# [193/1852] -- Time: Data 0.39s, Epoch 4.53s -- TrainLoss 0.0107
# [194/1852] -- Time: Data 0.41s, Epoch 4.34s -- TrainLoss 0.0108 -- ValLoss 0.0106 -- ValPSNR 19.7691
# [195/1852] -- Time: Data 0.41s, Epoch 4.35s -- TrainLoss 0.0111
# [196/1852] -- Time: Data 0.42s, Epoch 4.33s -- TrainLoss 0.0108 -- ValLoss 0.0098 -- ValPSNR 20.1743
# [197/1852] -- Time: Data 0.44s, Epoch 4.39s -- TrainLoss 0.0109
# [198/1852] -- Time: Data 0.43s, Epoch 4.38s -- TrainLoss 0.0110 -- ValLoss 0.0099 -- ValPSNR 20.1345
# [199/1852] -- Time: Data 0.41s, Epoch 4.45s -- TrainLoss 0.0111
# [200/1852] -- Time: Data 0.38s, Epoch 4.33s -- TrainLoss 0.0108 -- ValLoss 0.0115 -- ValPSNR 19.5210
# [201/1852] -- Time: Data 0.41s, Epoch 4.39s -- TrainLoss 0.0107
# [202/1852] -- Time: Data 0.45s, Epoch 4.42s -- TrainLoss 0.0106 -- ValLoss 0.0098 -- ValPSNR 20.2003
# [203/1852] -- Time: Data 0.40s, Epoch 4.36s -- TrainLoss 0.0108
# [204/1852] -- Time: Data 0.48s, Epoch 4.41s -- TrainLoss 0.0108 -- ValLoss 0.0099 -- ValPSNR 20.1484
# [205/1852] -- Time: Data 0.41s, Epoch 4.33s -- TrainLoss 0.0109
# [206/1852] -- Time: Data 0.39s, Epoch 4.42s -- TrainLoss 0.0108 -- ValLoss 0.0102 -- ValPSNR 19.9417
# [207/1852] -- Time: Data 0.37s, Epoch 4.28s -- TrainLoss 0.0108
# [208/1852] -- Time: Data 0.41s, Epoch 4.34s -- TrainLoss 0.0109 -- ValLoss 0.0101 -- ValPSNR 19.9974
# [209/1852] -- Time: Data 0.40s, Epoch 4.32s -- TrainLoss 0.0110
# [210/1852] -- Time: Data 0.40s, Epoch 4.37s -- TrainLoss 0.0109 -- ValLoss 0.0099 -- ValPSNR 20.1393
# [211/1852] -- Time: Data 0.42s, Epoch 4.41s -- TrainLoss 0.0110
# [212/1852] -- Time: Data 0.39s, Epoch 4.34s -- TrainLoss 0.0107 -- ValLoss 0.0103 -- ValPSNR 19.8729
# [213/1852] -- Time: Data 0.40s, Epoch 4.36s -- TrainLoss 0.0108
# [214/1852] -- Time: Data 0.43s, Epoch 4.40s -- TrainLoss 0.0110 -- ValLoss 0.0103 -- ValPSNR 19.9569
# [215/1852] -- Time: Data 0.42s, Epoch 4.33s -- TrainLoss 0.0108
# [216/1852] -- Time: Data 0.39s, Epoch 4.35s -- TrainLoss 0.0108 -- ValLoss 0.0104 -- ValPSNR 19.8774
# [217/1852] -- Time: Data 0.45s, Epoch 4.37s -- TrainLoss 0.0109
# [218/1852] -- Time: Data 0.38s, Epoch 4.30s -- TrainLoss 0.0107 -- ValLoss 0.0116 -- ValPSNR 19.4863
# [219/1852] -- Time: Data 0.42s, Epoch 4.33s -- TrainLoss 0.0105
# [220/1852] -- Time: Data 0.39s, Epoch 4.29s -- TrainLoss 0.0109 -- ValLoss 0.0102 -- ValPSNR 19.9408
# [221/1852] -- Time: Data 0.38s, Epoch 4.42s -- TrainLoss 0.0107
# [222/1852] -- Time: Data 0.41s, Epoch 4.48s -- TrainLoss 0.0110 -- ValLoss 0.0107 -- ValPSNR 19.7048
# [223/1852] -- Time: Data 0.38s, Epoch 4.35s -- TrainLoss 0.0108
# [224/1852] -- Time: Data 0.40s, Epoch 4.32s -- TrainLoss 0.0106 -- ValLoss 0.0107 -- ValPSNR 19.7506
# [225/1852] -- Time: Data 0.40s, Epoch 4.33s -- TrainLoss 0.0107
# [226/1852] -- Time: Data 0.42s, Epoch 4.35s -- TrainLoss 0.0108 -- ValLoss 0.0097 -- ValPSNR 20.2926
# [227/1852] -- Time: Data 0.41s, Epoch 4.39s -- TrainLoss 0.0110
# [228/1852] -- Time: Data 0.40s, Epoch 4.33s -- TrainLoss 0.0106 -- ValLoss 0.0106 -- ValPSNR 19.7746
# [229/1852] -- Time: Data 0.43s, Epoch 4.49s -- TrainLoss 0.0108
# [230/1852] -- Time: Data 0.43s, Epoch 4.38s -- TrainLoss 0.0108 -- ValLoss 0.0109 -- ValPSNR 19.7384
# [231/1852] -- Time: Data 0.40s, Epoch 4.34s -- TrainLoss 0.0108
# [232/1852] -- Time: Data 0.45s, Epoch 4.39s -- TrainLoss 0.0108 -- ValLoss 0.0108 -- ValPSNR 19.7339
# [233/1852] -- Time: Data 0.45s, Epoch 4.41s -- TrainLoss 0.0108
# [234/1852] -- Time: Data 0.42s, Epoch 4.49s -- TrainLoss 0.0106 -- ValLoss 0.0105 -- ValPSNR 19.8172
# [235/1852] -- Time: Data 0.40s, Epoch 4.35s -- TrainLoss 0.0106
# [236/1852] -- Time: Data 0.43s, Epoch 4.38s -- TrainLoss 0.0109 -- ValLoss 0.0107 -- ValPSNR 19.7578
# [237/1852] -- Time: Data 0.38s, Epoch 4.40s -- TrainLoss 0.0107
# [238/1852] -- Time: Data 0.42s, Epoch 4.33s -- TrainLoss 0.0110 -- ValLoss 0.0096 -- ValPSNR 20.3723
# [239/1852] -- Time: Data 0.41s, Epoch 4.30s -- TrainLoss 0.0109
# [240/1852] -- Time: Data 0.38s, Epoch 4.29s -- TrainLoss 0.0110 -- ValLoss 0.0107 -- ValPSNR 19.7315
# [241/1852] -- Time: Data 0.41s, Epoch 4.31s -- TrainLoss 0.0108
# [242/1852] -- Time: Data 0.39s, Epoch 4.40s -- TrainLoss 0.0110 -- ValLoss 0.0123 -- ValPSNR 19.3882
# [243/1852] -- Time: Data 0.40s, Epoch 4.31s -- TrainLoss 0.0106
# [244/1852] -- Time: Data 0.37s, Epoch 4.37s -- TrainLoss 0.0108 -- ValLoss 0.0100 -- ValPSNR 20.0679
# [245/1852] -- Time: Data 0.39s, Epoch 4.29s -- TrainLoss 0.0109
# [246/1852] -- Time: Data 0.44s, Epoch 4.35s -- TrainLoss 0.0106 -- ValLoss 0.0103 -- ValPSNR 19.8689
# [247/1852] -- Time: Data 0.37s, Epoch 4.28s -- TrainLoss 0.0109
# [248/1852] -- Time: Data 0.40s, Epoch 4.33s -- TrainLoss 0.0108 -- ValLoss 0.0116 -- ValPSNR 19.5232
# [249/1852] -- Time: Data 0.37s, Epoch 4.27s -- TrainLoss 0.0108
# [250/1852] -- Time: Data 0.38s, Epoch 4.43s -- TrainLoss 0.0109 -- ValLoss 0.0100 -- ValPSNR 20.0269
# [251/1852] -- Time: Data 0.42s, Epoch 4.40s -- TrainLoss 0.0109
# [252/1852] -- Time: Data 0.41s, Epoch 4.29s -- TrainLoss 0.0105 -- ValLoss 0.0101 -- ValPSNR 20.0238
# [253/1852] -- Time: Data 0.41s, Epoch 4.34s -- TrainLoss 0.0108
# [254/1852] -- Time: Data 0.45s, Epoch 4.38s -- TrainLoss 0.0106 -- ValLoss 0.0103 -- ValPSNR 19.9182
# [255/1852] -- Time: Data 0.39s, Epoch 4.29s -- TrainLoss 0.0107
# [256/1852] -- Time: Data 0.40s, Epoch 4.35s -- TrainLoss 0.0106 -- ValLoss 0.0101 -- ValPSNR 20.0033
# [257/1852] -- Time: Data 0.42s, Epoch 4.37s -- TrainLoss 0.0106
# [258/1852] -- Time: Data 0.38s, Epoch 4.31s -- TrainLoss 0.0108 -- ValLoss 0.0101 -- ValPSNR 19.9946
# [259/1852] -- Time: Data 0.38s, Epoch 4.30s -- TrainLoss 0.0108
# [260/1852] -- Time: Data 0.39s, Epoch 4.30s -- TrainLoss 0.0109 -- ValLoss 0.0100 -- ValPSNR 20.0547
# [261/1852] -- Time: Data 0.37s, Epoch 4.29s -- TrainLoss 0.0104
# [262/1852] -- Time: Data 0.41s, Epoch 4.35s -- TrainLoss 0.0111 -- ValLoss 0.0101 -- ValPSNR 20.0263
# [263/1852] -- Time: Data 0.42s, Epoch 4.34s -- TrainLoss 0.0108
# [264/1852] -- Time: Data 0.38s, Epoch 4.28s -- TrainLoss 0.0108 -- ValLoss 0.0106 -- ValPSNR 19.7823
# [265/1852] -- Time: Data 0.40s, Epoch 4.34s -- TrainLoss 0.0108
# [266/1852] -- Time: Data 0.41s, Epoch 4.31s -- TrainLoss 0.0108 -- ValLoss 0.0109 -- ValPSNR 19.6960
# [267/1852] -- Time: Data 0.42s, Epoch 4.37s -- TrainLoss 0.0108
# [268/1852] -- Time: Data 0.39s, Epoch 4.29s -- TrainLoss 0.0109 -- ValLoss 0.0107 -- ValPSNR 19.7261
# [269/1852] -- Time: Data 0.39s, Epoch 4.30s -- TrainLoss 0.0109
# [270/1852] -- Time: Data 0.39s, Epoch 4.35s -- TrainLoss 0.0106 -- ValLoss 0.0104 -- ValPSNR 19.8245
# [271/1852] -- Time: Data 0.37s, Epoch 4.29s -- TrainLoss 0.0109
# [272/1852] -- Time: Data 0.43s, Epoch 4.55s -- TrainLoss 0.0108 -- ValLoss 0.0098 -- ValPSNR 20.2155
# [273/1852] -- Time: Data 0.41s, Epoch 4.32s -- TrainLoss 0.0107
# [274/1852] -- Time: Data 0.37s, Epoch 4.42s -- TrainLoss 0.0108 -- ValLoss 0.0102 -- ValPSNR 19.9604
# [275/1852] -- Time: Data 0.41s, Epoch 4.51s -- TrainLoss 0.0107
# [276/1852] -- Time: Data 0.39s, Epoch 4.38s -- TrainLoss 0.0108 -- ValLoss 0.0106 -- ValPSNR 19.7895
# [277/1852] -- Time: Data 0.39s, Epoch 4.30s -- TrainLoss 0.0108
# [278/1852] -- Time: Data 0.39s, Epoch 4.31s -- TrainLoss 0.0108 -- ValLoss 0.0102 -- ValPSNR 19.9467
# [279/1852] -- Time: Data 0.39s, Epoch 4.35s -- TrainLoss 0.0104
# [280/1852] -- Time: Data 0.43s, Epoch 4.34s -- TrainLoss 0.0107 -- ValLoss 0.0100 -- ValPSNR 20.0568
# [281/1852] -- Time: Data 0.36s, Epoch 4.41s -- TrainLoss 0.0110
# [282/1852] -- Time: Data 0.38s, Epoch 4.31s -- TrainLoss 0.0107 -- ValLoss 0.0107 -- ValPSNR 19.7393
# [283/1852] -- Time: Data 0.41s, Epoch 4.37s -- TrainLoss 0.0107
# [284/1852] -- Time: Data 0.39s, Epoch 4.34s -- TrainLoss 0.0108 -- ValLoss 0.0114 -- ValPSNR 19.5760
# [285/1852] -- Time: Data 0.39s, Epoch 4.33s -- TrainLoss 0.0106
# [286/1852] -- Time: Data 0.47s, Epoch 4.47s -- TrainLoss 0.0107 -- ValLoss 0.0107 -- ValPSNR 19.7303
# [287/1852] -- Time: Data 0.37s, Epoch 4.46s -- TrainLoss 0.0107
# [288/1852] -- Time: Data 0.34s, Epoch 4.24s -- TrainLoss 0.0106 -- ValLoss 0.0098 -- ValPSNR 20.1870
# [289/1852] -- Time: Data 0.40s, Epoch 4.31s -- TrainLoss 0.0110
# [290/1852] -- Time: Data 0.43s, Epoch 4.37s -- TrainLoss 0.0107 -- ValLoss 0.0108 -- ValPSNR 19.6988
# [291/1852] -- Time: Data 0.36s, Epoch 4.26s -- TrainLoss 0.0106
# [292/1852] -- Time: Data 0.40s, Epoch 4.29s -- TrainLoss 0.0108 -- ValLoss 0.0105 -- ValPSNR 19.7936
# [293/1852] -- Time: Data 0.40s, Epoch 4.33s -- TrainLoss 0.0105
# [294/1852] -- Time: Data 0.42s, Epoch 4.33s -- TrainLoss 0.0108 -- ValLoss 0.0100 -- ValPSNR 19.9994
# [295/1852] -- Time: Data 0.44s, Epoch 4.44s -- TrainLoss 0.0106
# [296/1852] -- Time: Data 0.38s, Epoch 4.42s -- TrainLoss 0.0108 -- ValLoss 0.0118 -- ValPSNR 19.4703
# [297/1852] -- Time: Data 0.42s, Epoch 4.32s -- TrainLoss 0.0108
# [298/1852] -- Time: Data 0.40s, Epoch 4.30s -- TrainLoss 0.0107 -- ValLoss 0.0099 -- ValPSNR 20.1152
# [299/1852] -- Time: Data 0.38s, Epoch 4.28s -- TrainLoss 0.0107
# [300/1852] -- Time: Data 0.37s, Epoch 4.28s -- TrainLoss 0.0105 -- ValLoss 0.0109 -- ValPSNR 19.6981
# [301/1852] -- Time: Data 0.36s, Epoch 4.25s -- TrainLoss 0.0107
# [302/1852] -- Time: Data 0.40s, Epoch 4.36s -- TrainLoss 0.0107 -- ValLoss 0.0099 -- ValPSNR 20.1104
# [303/1852] -- Time: Data 0.40s, Epoch 4.54s -- TrainLoss 0.0108
# [304/1852] -- Time: Data 0.38s, Epoch 4.30s -- TrainLoss 0.0106 -- ValLoss 0.0100 -- ValPSNR 20.0240
# [305/1852] -- Time: Data 0.39s, Epoch 4.31s -- TrainLoss 0.0105
# [306/1852] -- Time: Data 0.45s, Epoch 4.36s -- TrainLoss 0.0107 -- ValLoss 0.0104 -- ValPSNR 19.8805
# [307/1852] -- Time: Data 0.42s, Epoch 4.35s -- TrainLoss 0.0108
# [308/1852] -- Time: Data 0.38s, Epoch 4.34s -- TrainLoss 0.0105 -- ValLoss 0.0099 -- ValPSNR 20.1258
# [309/1852] -- Time: Data 0.39s, Epoch 4.32s -- TrainLoss 0.0107
# [310/1852] -- Time: Data 0.37s, Epoch 4.29s -- TrainLoss 0.0109 -- ValLoss 0.0101 -- ValPSNR 19.9759
# [311/1852] -- Time: Data 0.44s, Epoch 4.37s -- TrainLoss 0.0105
# [312/1852] -- Time: Data 0.44s, Epoch 4.46s -- TrainLoss 0.0107 -- ValLoss 0.0100 -- ValPSNR 20.0423
# [313/1852] -- Time: Data 0.39s, Epoch 4.30s -- TrainLoss 0.0106
# [314/1852] -- Time: Data 0.38s, Epoch 4.49s -- TrainLoss 0.0106 -- ValLoss 0.0100 -- ValPSNR 20.0342
# [315/1852] -- Time: Data 0.40s, Epoch 4.30s -- TrainLoss 0.0106
# [316/1852] -- Time: Data 0.37s, Epoch 4.28s -- TrainLoss 0.0106 -- ValLoss 0.0100 -- ValPSNR 20.0838
# [317/1852] -- Time: Data 0.39s, Epoch 4.31s -- TrainLoss 0.0107
# [318/1852] -- Time: Data 0.37s, Epoch 4.26s -- TrainLoss 0.0107 -- ValLoss 0.0116 -- ValPSNR 19.5404
# [319/1852] -- Time: Data 0.37s, Epoch 4.27s -- TrainLoss 0.0106
# [320/1852] -- Time: Data 0.42s, Epoch 4.35s -- TrainLoss 0.0107 -- ValLoss 0.0104 -- ValPSNR 19.8577
# [321/1852] -- Time: Data 0.41s, Epoch 4.31s -- TrainLoss 0.0107
# [322/1852] -- Time: Data 0.38s, Epoch 4.42s -- TrainLoss 0.0107 -- ValLoss 0.0095 -- ValPSNR 20.3809
# [323/1852] -- Time: Data 0.42s, Epoch 4.32s -- TrainLoss 0.0107
# [324/1852] -- Time: Data 0.41s, Epoch 4.31s -- TrainLoss 0.0107 -- ValLoss 0.0106 -- ValPSNR 19.8588
# [325/1852] -- Time: Data 0.42s, Epoch 4.32s -- TrainLoss 0.0106
# [326/1852] -- Time: Data 0.39s, Epoch 4.30s -- TrainLoss 0.0107 -- ValLoss 0.0102 -- ValPSNR 19.9439
# [327/1852] -- Time: Data 0.43s, Epoch 4.33s -- TrainLoss 0.0107
# [328/1852] -- Time: Data 0.39s, Epoch 4.31s -- TrainLoss 0.0107 -- ValLoss 0.0098 -- ValPSNR 20.1997
# [329/1852] -- Time: Data 0.37s, Epoch 4.36s -- TrainLoss 0.0109
# [330/1852] -- Time: Data 0.37s, Epoch 4.30s -- TrainLoss 0.0106 -- ValLoss 0.0107 -- ValPSNR 19.7279
# [331/1852] -- Time: Data 0.41s, Epoch 4.39s -- TrainLoss 0.0107
# [332/1852] -- Time: Data 0.48s, Epoch 4.43s -- TrainLoss 0.0104 -- ValLoss 0.0107 -- ValPSNR 19.7788
# [333/1852] -- Time: Data 0.41s, Epoch 4.41s -- TrainLoss 0.0107
# [334/1852] -- Time: Data 0.42s, Epoch 4.34s -- TrainLoss 0.0108 -- ValLoss 0.0102 -- ValPSNR 19.9671
# [335/1852] -- Time: Data 0.40s, Epoch 4.33s -- TrainLoss 0.0106
# [336/1852] -- Time: Data 0.39s, Epoch 4.33s -- TrainLoss 0.0104 -- ValLoss 0.0106 -- ValPSNR 19.7747
# [337/1852] -- Time: Data 0.39s, Epoch 4.31s -- TrainLoss 0.0106
# [338/1852] -- Time: Data 0.41s, Epoch 4.32s -- TrainLoss 0.0104 -- ValLoss 0.0094 -- ValPSNR 20.5134
# [339/1852] -- Time: Data 0.44s, Epoch 4.48s -- TrainLoss 0.0106
# [340/1852] -- Time: Data 0.38s, Epoch 4.34s -- TrainLoss 0.0106 -- ValLoss 0.0097 -- ValPSNR 20.1925
# [341/1852] -- Time: Data 0.43s, Epoch 4.38s -- TrainLoss 0.0105
# [342/1852] -- Time: Data 0.40s, Epoch 4.30s -- TrainLoss 0.0105 -- ValLoss 0.0108 -- ValPSNR 19.7170
# [343/1852] -- Time: Data 0.41s, Epoch 4.39s -- TrainLoss 0.0108
# [344/1852] -- Time: Data 0.38s, Epoch 4.30s -- TrainLoss 0.0109 -- ValLoss 0.0104 -- ValPSNR 19.8572
# [345/1852] -- Time: Data 0.37s, Epoch 4.52s -- TrainLoss 0.0107
# [346/1852] -- Time: Data 0.42s, Epoch 4.45s -- TrainLoss 0.0106 -- ValLoss 0.0100 -- ValPSNR 20.0433
# [347/1852] -- Time: Data 0.41s, Epoch 4.42s -- TrainLoss 0.0106
# [348/1852] -- Time: Data 0.39s, Epoch 4.27s -- TrainLoss 0.0105 -- ValLoss 0.0118 -- ValPSNR 19.4710
# [349/1852] -- Time: Data 0.44s, Epoch 4.37s -- TrainLoss 0.0107
# [350/1852] -- Time: Data 0.38s, Epoch 4.35s -- TrainLoss 0.0104 -- ValLoss 0.0107 -- ValPSNR 19.7361
# [351/1852] -- Time: Data 0.43s, Epoch 4.43s -- TrainLoss 0.0107
# [352/1852] -- Time: Data 0.41s, Epoch 4.31s -- TrainLoss 0.0108 -- ValLoss 0.0104 -- ValPSNR 19.8717
# [353/1852] -- Time: Data 0.40s, Epoch 4.32s -- TrainLoss 0.0106
# [354/1852] -- Time: Data 0.39s, Epoch 4.33s -- TrainLoss 0.0104 -- ValLoss 0.0104 -- ValPSNR 19.8579
# [355/1852] -- Time: Data 0.38s, Epoch 4.27s -- TrainLoss 0.0107
# [356/1852] -- Time: Data 0.46s, Epoch 4.40s -- TrainLoss 0.0105 -- ValLoss 0.0109 -- ValPSNR 19.6650
# [357/1852] -- Time: Data 0.38s, Epoch 4.44s -- TrainLoss 0.0106
# [358/1852] -- Time: Data 0.43s, Epoch 4.38s -- TrainLoss 0.0106 -- ValLoss 0.0102 -- ValPSNR 19.9647
# [359/1852] -- Time: Data 0.40s, Epoch 4.30s -- TrainLoss 0.0105
# [360/1852] -- Time: Data 0.40s, Epoch 4.29s -- TrainLoss 0.0109 -- ValLoss 0.0110 -- ValPSNR 19.6300
# [361/1852] -- Time: Data 0.44s, Epoch 4.37s -- TrainLoss 0.0107
# [362/1852] -- Time: Data 0.38s, Epoch 4.28s -- TrainLoss 0.0109 -- ValLoss 0.0100 -- ValPSNR 20.0284
# [363/1852] -- Time: Data 0.38s, Epoch 4.29s -- TrainLoss 0.0108
# [364/1852] -- Time: Data 0.38s, Epoch 4.48s -- TrainLoss 0.0106 -- ValLoss 0.0096 -- ValPSNR 20.3221
# [365/1852] -- Time: Data 0.45s, Epoch 4.37s -- TrainLoss 0.0106
# [366/1852] -- Time: Data 0.39s, Epoch 4.29s -- TrainLoss 0.0104 -- ValLoss 0.0102 -- ValPSNR 19.9189
# [367/1852] -- Time: Data 0.44s, Epoch 4.35s -- TrainLoss 0.0107
# [368/1852] -- Time: Data 0.40s, Epoch 4.46s -- TrainLoss 0.0106 -- ValLoss 0.0117 -- ValPSNR 19.5119
# [369/1852] -- Time: Data 0.40s, Epoch 4.35s -- TrainLoss 0.0106
# [370/1852] -- Time: Data 0.39s, Epoch 4.31s -- TrainLoss 0.0104 -- ValLoss 0.0109 -- ValPSNR 19.6692
# [371/1852] -- Time: Data 0.40s, Epoch 4.38s -- TrainLoss 0.0105
# [372/1852] -- Time: Data 0.38s, Epoch 4.34s -- TrainLoss 0.0105 -- ValLoss 0.0100 -- ValPSNR 20.0521
# [373/1852] -- Time: Data 0.42s, Epoch 4.52s -- TrainLoss 0.0105
# [374/1852] -- Time: Data 0.39s, Epoch 4.30s -- TrainLoss 0.0105 -- ValLoss 0.0106 -- ValPSNR 19.7732
# [375/1852] -- Time: Data 0.38s, Epoch 4.29s -- TrainLoss 0.0104
# [376/1852] -- Time: Data 0.39s, Epoch 4.30s -- TrainLoss 0.0107 -- ValLoss 0.0094 -- ValPSNR 20.4450
# [377/1852] -- Time: Data 0.38s, Epoch 4.28s -- TrainLoss 0.0109
# [378/1852] -- Time: Data 0.37s, Epoch 4.42s -- TrainLoss 0.0105 -- ValLoss 0.0097 -- ValPSNR 20.2850
# [379/1852] -- Time: Data 0.42s, Epoch 4.35s -- TrainLoss 0.0104
# [380/1852] -- Time: Data 0.39s, Epoch 4.32s -- TrainLoss 0.0108 -- ValLoss 0.0108 -- ValPSNR 19.7074
# [381/1852] -- Time: Data 0.42s, Epoch 4.37s -- TrainLoss 0.0104
# [382/1852] -- Time: Data 0.38s, Epoch 4.50s -- TrainLoss 0.0105 -- ValLoss 0.0098 -- ValPSNR 20.1719
# [383/1852] -- Time: Data 0.40s, Epoch 4.34s -- TrainLoss 0.0106
# [384/1852] -- Time: Data 0.40s, Epoch 4.32s -- TrainLoss 0.0106 -- ValLoss 0.0100 -- ValPSNR 20.0639
# [385/1852] -- Time: Data 0.46s, Epoch 4.41s -- TrainLoss 0.0107
# [386/1852] -- Time: Data 0.43s, Epoch 4.36s -- TrainLoss 0.0107 -- ValLoss 0.0109 -- ValPSNR 19.7177
# [387/1852] -- Time: Data 0.43s, Epoch 4.35s -- TrainLoss 0.0107
# [388/1852] -- Time: Data 0.41s, Epoch 4.31s -- TrainLoss 0.0104 -- ValLoss 0.0105 -- ValPSNR 19.7989
# [389/1852] -- Time: Data 0.41s, Epoch 4.33s -- TrainLoss 0.0106
# [390/1852] -- Time: Data 0.38s, Epoch 4.28s -- TrainLoss 0.0106 -- ValLoss 0.0103 -- ValPSNR 19.8620
# [391/1852] -- Time: Data 0.39s, Epoch 4.33s -- TrainLoss 0.0104
# [392/1852] -- Time: Data 0.40s, Epoch 4.38s -- TrainLoss 0.0106 -- ValLoss 0.0103 -- ValPSNR 19.8632
# [393/1852] -- Time: Data 0.41s, Epoch 4.31s -- TrainLoss 0.0108
# [394/1852] -- Time: Data 0.40s, Epoch 4.37s -- TrainLoss 0.0106 -- ValLoss 0.0108 -- ValPSNR 19.7162
# [395/1852] -- Time: Data 0.41s, Epoch 4.34s -- TrainLoss 0.0109
# [396/1852] -- Time: Data 0.39s, Epoch 4.39s -- TrainLoss 0.0106 -- ValLoss 0.0106 -- ValPSNR 19.8142
# [397/1852] -- Time: Data 0.41s, Epoch 4.33s -- TrainLoss 0.0108
# [398/1852] -- Time: Data 0.38s, Epoch 4.29s -- TrainLoss 0.0104 -- ValLoss 0.0105 -- ValPSNR 19.8339
# [399/1852] -- Time: Data 0.37s, Epoch 4.28s -- TrainLoss 0.0106
# [400/1852] -- Time: Data 0.39s, Epoch 4.32s -- TrainLoss 0.0104 -- ValLoss 0.0101 -- ValPSNR 19.9441
# [401/1852] -- Time: Data 0.41s, Epoch 4.35s -- TrainLoss 0.0104
# [402/1852] -- Time: Data 0.39s, Epoch 4.32s -- TrainLoss 0.0108 -- ValLoss 0.0100 -- ValPSNR 20.0499
# [403/1852] -- Time: Data 0.38s, Epoch 4.27s -- TrainLoss 0.0105
# [404/1852] -- Time: Data 0.38s, Epoch 4.28s -- TrainLoss 0.0106 -- ValLoss 0.0110 -- ValPSNR 19.7241
# [405/1852] -- Time: Data 0.41s, Epoch 4.38s -- TrainLoss 0.0106
# [406/1852] -- Time: Data 0.40s, Epoch 4.31s -- TrainLoss 0.0107 -- ValLoss 0.0097 -- ValPSNR 20.2093
# [407/1852] -- Time: Data 0.38s, Epoch 4.29s -- TrainLoss 0.0106
# [408/1852] -- Time: Data 0.40s, Epoch 4.52s -- TrainLoss 0.0105 -- ValLoss 0.0103 -- ValPSNR 19.8948
# [409/1852] -- Time: Data 0.38s, Epoch 4.31s -- TrainLoss 0.0104
# [410/1852] -- Time: Data 0.40s, Epoch 4.32s -- TrainLoss 0.0107 -- ValLoss 0.0101 -- ValPSNR 19.9798
# [411/1852] -- Time: Data 0.38s, Epoch 4.30s -- TrainLoss 0.0107
# [412/1852] -- Time: Data 0.38s, Epoch 4.30s -- TrainLoss 0.0105 -- ValLoss 0.0100 -- ValPSNR 20.0096
# [413/1852] -- Time: Data 0.41s, Epoch 4.53s -- TrainLoss 0.0106
# [414/1852] -- Time: Data 0.38s, Epoch 4.36s -- TrainLoss 0.0105 -- ValLoss 0.0099 -- ValPSNR 20.0712
# [415/1852] -- Time: Data 0.38s, Epoch 4.29s -- TrainLoss 0.0105
# [416/1852] -- Time: Data 0.41s, Epoch 4.32s -- TrainLoss 0.0104 -- ValLoss 0.0105 -- ValPSNR 19.8578
# [417/1852] -- Time: Data 0.41s, Epoch 4.55s -- TrainLoss 0.0104
# [418/1852] -- Time: Data 0.45s, Epoch 4.38s -- TrainLoss 0.0106 -- ValLoss 0.0101 -- ValPSNR 19.9962
# [419/1852] -- Time: Data 0.43s, Epoch 4.35s -- TrainLoss 0.0103
# [420/1852] -- Time: Data 0.40s, Epoch 4.30s -- TrainLoss 0.0105 -- ValLoss 0.0106 -- ValPSNR 19.7668
# [421/1852] -- Time: Data 0.41s, Epoch 4.34s -- TrainLoss 0.0105
# [422/1852] -- Time: Data 0.41s, Epoch 4.30s -- TrainLoss 0.0106 -- ValLoss 0.0099 -- ValPSNR 20.1208
# [423/1852] -- Time: Data 0.42s, Epoch 4.35s -- TrainLoss 0.0107
# [424/1852] -- Time: Data 0.38s, Epoch 4.28s -- TrainLoss 0.0105 -- ValLoss 0.0105 -- ValPSNR 19.8348
# [425/1852] -- Time: Data 0.43s, Epoch 4.36s -- TrainLoss 0.0107
# [426/1852] -- Time: Data 0.37s, Epoch 4.28s -- TrainLoss 0.0108 -- ValLoss 0.0105 -- ValPSNR 19.8092
# [427/1852] -- Time: Data 0.43s, Epoch 4.36s -- TrainLoss 0.0104
# [428/1852] -- Time: Data 0.37s, Epoch 4.32s -- TrainLoss 0.0105 -- ValLoss 0.0102 -- ValPSNR 19.9945
# [429/1852] -- Time: Data 0.42s, Epoch 4.35s -- TrainLoss 0.0102
# [430/1852] -- Time: Data 0.38s, Epoch 4.30s -- TrainLoss 0.0105 -- ValLoss 0.0106 -- ValPSNR 19.7714
# [431/1852] -- Time: Data 0.40s, Epoch 4.43s -- TrainLoss 0.0105
# [432/1852] -- Time: Data 0.39s, Epoch 4.30s -- TrainLoss 0.0106 -- ValLoss 0.0110 -- ValPSNR 19.6664
# [433/1852] -- Time: Data 0.38s, Epoch 4.30s -- TrainLoss 0.0105
# [434/1852] -- Time: Data 0.41s, Epoch 4.42s -- TrainLoss 0.0108 -- ValLoss 0.0104 -- ValPSNR 19.8710
# [435/1852] -- Time: Data 0.37s, Epoch 4.30s -- TrainLoss 0.0109
# [436/1852] -- Time: Data 0.39s, Epoch 4.31s -- TrainLoss 0.0105 -- ValLoss 0.0099 -- ValPSNR 20.1018
# [437/1852] -- Time: Data 0.41s, Epoch 4.34s -- TrainLoss 0.0103
# [438/1852] -- Time: Data 0.42s, Epoch 4.39s -- TrainLoss 0.0106 -- ValLoss 0.0097 -- ValPSNR 20.2289
# [439/1852] -- Time: Data 0.42s, Epoch 4.33s -- TrainLoss 0.0106
# [440/1852] -- Time: Data 0.40s, Epoch 4.31s -- TrainLoss 0.0104 -- ValLoss 0.0105 -- ValPSNR 19.8004
# [441/1852] -- Time: Data 0.38s, Epoch 4.31s -- TrainLoss 0.0103
# [442/1852] -- Time: Data 0.43s, Epoch 4.54s -- TrainLoss 0.0105 -- ValLoss 0.0110 -- ValPSNR 19.7564
# [443/1852] -- Time: Data 0.39s, Epoch 4.31s -- TrainLoss 0.0105
# [444/1852] -- Time: Data 0.44s, Epoch 4.44s -- TrainLoss 0.0105 -- ValLoss 0.0097 -- ValPSNR 20.2729
# [445/1852] -- Time: Data 0.38s, Epoch 4.34s -- TrainLoss 0.0106
# [446/1852] -- Time: Data 0.43s, Epoch 4.43s -- TrainLoss 0.0106 -- ValLoss 0.0101 -- ValPSNR 20.0033
# [447/1852] -- Time: Data 0.40s, Epoch 4.33s -- TrainLoss 0.0106
# [448/1852] -- Time: Data 0.39s, Epoch 4.30s -- TrainLoss 0.0105 -- ValLoss 0.0103 -- ValPSNR 19.8605
# [449/1852] -- Time: Data 0.40s, Epoch 4.38s -- TrainLoss 0.0106
# [450/1852] -- Time: Data 0.39s, Epoch 4.29s -- TrainLoss 0.0106 -- ValLoss 0.0112 -- ValPSNR 19.6148
# [451/1852] -- Time: Data 0.40s, Epoch 4.52s -- TrainLoss 0.0105
# [452/1852] -- Time: Data 0.40s, Epoch 4.30s -- TrainLoss 0.0106 -- ValLoss 0.0106 -- ValPSNR 19.7666
# [453/1852] -- Time: Data 0.40s, Epoch 4.31s -- TrainLoss 0.0107
# [454/1852] -- Time: Data 0.41s, Epoch 4.32s -- TrainLoss 0.0104 -- ValLoss 0.0099 -- ValPSNR 20.1144
# [455/1852] -- Time: Data 0.42s, Epoch 4.34s -- TrainLoss 0.0105
# [456/1852] -- Time: Data 0.42s, Epoch 4.36s -- TrainLoss 0.0106 -- ValLoss 0.0106 -- ValPSNR 19.7439
# [457/1852] -- Time: Data 0.38s, Epoch 4.27s -- TrainLoss 0.0106
# [458/1852] -- Time: Data 0.40s, Epoch 4.36s -- TrainLoss 0.0106 -- ValLoss 0.0104 -- ValPSNR 19.8288
# [459/1852] -- Time: Data 0.42s, Epoch 4.36s -- TrainLoss 0.0104
# [460/1852] -- Time: Data 0.46s, Epoch 4.41s -- TrainLoss 0.0105 -- ValLoss 0.0102 -- ValPSNR 19.9050
# [461/1852] -- Time: Data 0.37s, Epoch 4.30s -- TrainLoss 0.0106
# [462/1852] -- Time: Data 0.40s, Epoch 4.32s -- TrainLoss 0.0105 -- ValLoss 0.0102 -- ValPSNR 19.9663
# [463/1852] -- Time: Data 0.41s, Epoch 4.35s -- TrainLoss 0.0103
# [464/1852] -- Time: Data 0.39s, Epoch 4.31s -- TrainLoss 0.0104 -- ValLoss 0.0106 -- ValPSNR 19.7693
# [465/1852] -- Time: Data 0.38s, Epoch 4.28s -- TrainLoss 0.0104
# [466/1852] -- Time: Data 0.41s, Epoch 4.31s -- TrainLoss 0.0104 -- ValLoss 0.0101 -- ValPSNR 19.9756
# [467/1852] -- Time: Data 0.38s, Epoch 4.28s -- TrainLoss 0.0107
# [468/1852] -- Time: Data 0.40s, Epoch 4.37s -- TrainLoss 0.0106 -- ValLoss 0.0111 -- ValPSNR 19.6272
# [469/1852] -- Time: Data 0.43s, Epoch 4.33s -- TrainLoss 0.0103
# [470/1852] -- Time: Data 0.38s, Epoch 4.28s -- TrainLoss 0.0103 -- ValLoss 0.0105 -- ValPSNR 19.7913
# [471/1852] -- Time: Data 0.39s, Epoch 4.40s -- TrainLoss 0.0105
# [472/1852] -- Time: Data 0.40s, Epoch 4.28s -- TrainLoss 0.0105 -- ValLoss 0.0103 -- ValPSNR 19.8738
# [473/1852] -- Time: Data 0.40s, Epoch 4.30s -- TrainLoss 0.0106
# [474/1852] -- Time: Data 0.40s, Epoch 4.28s -- TrainLoss 0.0104 -- ValLoss 0.0099 -- ValPSNR 20.1257
# [475/1852] -- Time: Data 0.40s, Epoch 4.52s -- TrainLoss 0.0105
# [476/1852] -- Time: Data 0.37s, Epoch 4.28s -- TrainLoss 0.0104 -- ValLoss 0.0100 -- ValPSNR 20.0578
# [477/1852] -- Time: Data 0.39s, Epoch 4.33s -- TrainLoss 0.0105
# [478/1852] -- Time: Data 0.38s, Epoch 4.44s -- TrainLoss 0.0106 -- ValLoss 0.0105 -- ValPSNR 19.8261
# [479/1852] -- Time: Data 0.41s, Epoch 4.32s -- TrainLoss 0.0105
# [480/1852] -- Time: Data 0.40s, Epoch 4.32s -- TrainLoss 0.0106 -- ValLoss 0.0103 -- ValPSNR 19.9380
# [481/1852] -- Time: Data 0.40s, Epoch 4.39s -- TrainLoss 0.0107
# [482/1852] -- Time: Data 0.39s, Epoch 4.30s -- TrainLoss 0.0103 -- ValLoss 0.0103 -- ValPSNR 19.9240
# [483/1852] -- Time: Data 0.38s, Epoch 4.35s -- TrainLoss 0.0106
# [484/1852] -- Time: Data 0.44s, Epoch 4.37s -- TrainLoss 0.0105 -- ValLoss 0.0100 -- ValPSNR 20.0491
# [485/1852] -- Time: Data 0.39s, Epoch 4.27s -- TrainLoss 0.0102
# [486/1852] -- Time: Data 0.40s, Epoch 4.31s -- TrainLoss 0.0105 -- ValLoss 0.0100 -- ValPSNR 20.0337
# [487/1852] -- Time: Data 0.40s, Epoch 4.32s -- TrainLoss 0.0106
# [488/1852] -- Time: Data 0.40s, Epoch 4.51s -- TrainLoss 0.0104 -- ValLoss 0.0108 -- ValPSNR 19.7067
# [489/1852] -- Time: Data 0.40s, Epoch 4.33s -- TrainLoss 0.0104
# [490/1852] -- Time: Data 0.40s, Epoch 4.32s -- TrainLoss 0.0103 -- ValLoss 0.0096 -- ValPSNR 20.2866
# [491/1852] -- Time: Data 0.38s, Epoch 4.32s -- TrainLoss 0.0105
# [492/1852] -- Time: Data 0.40s, Epoch 4.35s -- TrainLoss 0.0104 -- ValLoss 0.0114 -- ValPSNR 19.5657
# [493/1852] -- Time: Data 0.38s, Epoch 4.30s -- TrainLoss 0.0105
# [494/1852] -- Time: Data 0.41s, Epoch 4.31s -- TrainLoss 0.0106 -- ValLoss 0.0101 -- ValPSNR 20.0145
# [495/1852] -- Time: Data 0.37s, Epoch 4.37s -- TrainLoss 0.0105
# [496/1852] -- Time: Data 0.38s, Epoch 4.32s -- TrainLoss 0.0104 -- ValLoss 0.0100 -- ValPSNR 20.0271
# [497/1852] -- Time: Data 0.40s, Epoch 4.32s -- TrainLoss 0.0104
# [498/1852] -- Time: Data 0.38s, Epoch 4.37s -- TrainLoss 0.0103 -- ValLoss 0.0103 -- ValPSNR 19.9187
# [499/1852] -- Time: Data 0.43s, Epoch 4.42s -- TrainLoss 0.0106
# [500/1852] -- Time: Data 0.38s, Epoch 4.34s -- TrainLoss 0.0104 -- ValLoss 0.0106 -- ValPSNR 19.7928
# [501/1852] -- Time: Data 0.39s, Epoch 4.32s -- TrainLoss 0.0103
# [502/1852] -- Time: Data 0.43s, Epoch 4.34s -- TrainLoss 0.0108 -- ValLoss 0.0103 -- ValPSNR 19.9128
# [503/1852] -- Time: Data 0.39s, Epoch 4.28s -- TrainLoss 0.0106
# [504/1852] -- Time: Data 0.38s, Epoch 4.35s -- TrainLoss 0.0105 -- ValLoss 0.0103 -- ValPSNR 19.9438
# [505/1852] -- Time: Data 0.40s, Epoch 4.33s -- TrainLoss 0.0104
# [506/1852] -- Time: Data 0.39s, Epoch 4.30s -- TrainLoss 0.0105 -- ValLoss 0.0105 -- ValPSNR 19.8158
# [507/1852] -- Time: Data 0.39s, Epoch 4.38s -- TrainLoss 0.0107
# [508/1852] -- Time: Data 0.40s, Epoch 4.33s -- TrainLoss 0.0105 -- ValLoss 0.0099 -- ValPSNR 20.0921
# [526/1852] -- Time: Data 0.41s, Epoch 4.43s -- TrainLoss 0.0103 -- ValLoss 0.0101 -- ValPSNR 19.9692
# [527/1852] -- Time: Data 0.46s, Epoch 4.43s -- TrainLoss 0.0105
# [528/1852] -- Time: Data 0.47s, Epoch 4.40s -- TrainLoss 0.0105 -- ValLoss 0.0096 -- ValPSNR 20.2806
# [529/1852] -- Time: Data 0.39s, Epoch 4.32s -- TrainLoss 0.0103
# [530/1852] -- Time: Data 0.43s, Epoch 4.40s -- TrainLoss 0.0104 -- ValLoss 0.0099 -- ValPSNR 20.0945
# [531/1852] -- Time: Data 0.41s, Epoch 4.33s -- TrainLoss 0.0106
# [532/1852] -- Time: Data 0.39s, Epoch 4.31s -- TrainLoss 0.0104 -- ValLoss 0.0096 -- ValPSNR 20.3065
# [533/1852] -- Time: Data 0.38s, Epoch 4.29s -- TrainLoss 0.0103
# [534/1852] -- Time: Data 0.38s, Epoch 4.29s -- TrainLoss 0.0103 -- ValLoss 0.0103 -- ValPSNR 19.8966
# [535/1852] -- Time: Data 0.39s, Epoch 4.31s -- TrainLoss 0.0102
# [536/1852] -- Time: Data 0.39s, Epoch 4.40s -- TrainLoss 0.0104 -- ValLoss 0.0105 -- ValPSNR 19.8048
# [537/1852] -- Time: Data 0.40s, Epoch 4.34s -- TrainLoss 0.0106
# [538/1852] -- Time: Data 0.38s, Epoch 4.28s -- TrainLoss 0.0104 -- ValLoss 0.0107 -- ValPSNR 19.7495
# [539/1852] -- Time: Data 0.40s, Epoch 4.37s -- TrainLoss 0.0105
# [540/1852] -- Time: Data 0.41s, Epoch 4.32s -- TrainLoss 0.0107 -- ValLoss 0.0098 -- ValPSNR 20.1346
# [541/1852] -- Time: Data 0.39s, Epoch 4.30s -- TrainLoss 0.0106
# [542/1852] -- Time: Data 0.38s, Epoch 4.33s -- TrainLoss 0.0105 -- ValLoss 0.0099 -- ValPSNR 20.0688
# [543/1852] -- Time: Data 0.41s, Epoch 4.38s -- TrainLoss 0.0104
# [544/1852] -- Time: Data 0.38s, Epoch 4.28s -- TrainLoss 0.0103 -- ValLoss 0.0099 -- ValPSNR 20.0497
# [545/1852] -- Time: Data 0.40s, Epoch 4.43s -- TrainLoss 0.0104
# [546/1852] -- Time: Data 0.37s, Epoch 4.31s -- TrainLoss 0.0104 -- ValLoss 0.0117 -- ValPSNR 19.5041
# [547/1852] -- Time: Data 0.38s, Epoch 4.30s -- TrainLoss 0.0104
# [548/1852] -- Time: Data 0.43s, Epoch 4.35s -- TrainLoss 0.0105 -- ValLoss 0.0102 -- ValPSNR 19.9130
# [549/1852] -- Time: Data 0.38s, Epoch 4.29s -- TrainLoss 0.0105
# [550/1852] -- Time: Data 0.40s, Epoch 4.41s -- TrainLoss 0.0101 -- ValLoss 0.0105 -- ValPSNR 19.8499
# [551/1852] -- Time: Data 0.40s, Epoch 4.38s -- TrainLoss 0.0104
# [552/1852] -- Time: Data 0.43s, Epoch 4.32s -- TrainLoss 0.0106 -- ValLoss 0.0104 -- ValPSNR 19.8824
# [553/1852] -- Time: Data 0.39s, Epoch 4.35s -- TrainLoss 0.0102
# [554/1852] -- Time: Data 0.40s, Epoch 4.32s -- TrainLoss 0.0106 -- ValLoss 0.0111 -- ValPSNR 19.6713
# [555/1852] -- Time: Data 0.41s, Epoch 4.36s -- TrainLoss 0.0104
# [556/1852] -- Time: Data 0.40s, Epoch 4.32s -- TrainLoss 0.0105 -- ValLoss 0.0098 -- ValPSNR 20.1317
# [557/1852] -- Time: Data 0.39s, Epoch 4.34s -- TrainLoss 0.0103
# [558/1852] -- Time: Data 0.39s, Epoch 4.30s -- TrainLoss 0.0105 -- ValLoss 0.0099 -- ValPSNR 20.0790
# [559/1852] -- Time: Data 0.38s, Epoch 4.29s -- TrainLoss 0.0103
# [560/1852] -- Time: Data 0.40s, Epoch 4.31s -- TrainLoss 0.0103 -- ValLoss 0.0107 -- ValPSNR 19.7563
# [561/1852] -- Time: Data 0.42s, Epoch 4.50s -- TrainLoss 0.0102
# [562/1852] -- Time: Data 0.40s, Epoch 4.37s -- TrainLoss 0.0105 -- ValLoss 0.0110 -- ValPSNR 19.6765
# [563/1852] -- Time: Data 0.43s, Epoch 4.52s -- TrainLoss 0.0106
# [564/1852] -- Time: Data 0.39s, Epoch 4.30s -- TrainLoss 0.0105 -- ValLoss 0.0101 -- ValPSNR 19.9865
# [565/1852] -- Time: Data 0.41s, Epoch 4.32s -- TrainLoss 0.0104
# [566/1852] -- Time: Data 0.38s, Epoch 4.37s -- TrainLoss 0.0102 -- ValLoss 0.0100 -- ValPSNR 20.0106
# [567/1852] -- Time: Data 0.40s, Epoch 4.37s -- TrainLoss 0.0108
# [568/1852] -- Time: Data 0.39s, Epoch 4.34s -- TrainLoss 0.0104 -- ValLoss 0.0108 -- ValPSNR 19.7559
# [569/1852] -- Time: Data 0.40s, Epoch 4.28s -- TrainLoss 0.0105
# [570/1852] -- Time: Data 0.37s, Epoch 4.28s -- TrainLoss 0.0105 -- ValLoss 0.0105 -- ValPSNR 19.8267
# [571/1852] -- Time: Data 0.40s, Epoch 4.30s -- TrainLoss 0.0105
# [572/1852] -- Time: Data 0.41s, Epoch 4.34s -- TrainLoss 0.0105 -- ValLoss 0.0097 -- ValPSNR 20.2100
# [573/1852] -- Time: Data 0.41s, Epoch 4.33s -- TrainLoss 0.0106
# [574/1852] -- Time: Data 0.45s, Epoch 4.38s -- TrainLoss 0.0106 -- ValLoss 0.0108 -- ValPSNR 19.7217
# [575/1852] -- Time: Data 0.39s, Epoch 4.31s -- TrainLoss 0.0104
# [576/1852] -- Time: Data 0.41s, Epoch 4.31s -- TrainLoss 0.0104 -- ValLoss 0.0099 -- ValPSNR 20.1238
# [577/1852] -- Time: Data 0.40s, Epoch 4.30s -- TrainLoss 0.0104
# [578/1852] -- Time: Data 0.42s, Epoch 4.31s -- TrainLoss 0.0105 -- ValLoss 0.0108 -- ValPSNR 19.7234
# [579/1852] -- Time: Data 0.41s, Epoch 4.31s -- TrainLoss 0.0108
# [580/1852] -- Time: Data 0.39s, Epoch 4.48s -- TrainLoss 0.0103 -- ValLoss 0.0101 -- ValPSNR 19.9953
# [581/1852] -- Time: Data 0.40s, Epoch 4.33s -- TrainLoss 0.0101
# [582/1852] -- Time: Data 0.40s, Epoch 4.34s -- TrainLoss 0.0104 -- ValLoss 0.0108 -- ValPSNR 19.7394
# [583/1852] -- Time: Data 0.39s, Epoch 4.32s -- TrainLoss 0.0103
# [584/1852] -- Time: Data 0.40s, Epoch 4.42s -- TrainLoss 0.0102 -- ValLoss 0.0096 -- ValPSNR 20.3160
# [585/1852] -- Time: Data 0.42s, Epoch 4.48s -- TrainLoss 0.0104
# [586/1852] -- Time: Data 0.38s, Epoch 4.49s -- TrainLoss 0.0104 -- ValLoss 0.0106 -- ValPSNR 19.7796
# [587/1852] -- Time: Data 0.40s, Epoch 4.33s -- TrainLoss 0.0102
# [588/1852] -- Time: Data 0.39s, Epoch 4.30s -- TrainLoss 0.0103 -- ValLoss 0.0104 -- ValPSNR 19.8604
# [589/1852] -- Time: Data 0.41s, Epoch 4.35s -- TrainLoss 0.0104
# [590/1852] -- Time: Data 0.38s, Epoch 4.43s -- TrainLoss 0.0103 -- ValLoss 0.0113 -- ValPSNR 19.5956
# [591/1852] -- Time: Data 0.44s, Epoch 4.38s -- TrainLoss 0.0103
# [592/1852] -- Time: Data 0.41s, Epoch 4.31s -- TrainLoss 0.0105 -- ValLoss 0.0097 -- ValPSNR 20.2356
# [593/1852] -- Time: Data 0.39s, Epoch 4.30s -- TrainLoss 0.0104
# [594/1852] -- Time: Data 0.38s, Epoch 4.32s -- TrainLoss 0.0106 -- ValLoss 0.0108 -- ValPSNR 19.7111
# [595/1852] -- Time: Data 0.41s, Epoch 4.33s -- TrainLoss 0.0105
# [596/1852] -- Time: Data 0.43s, Epoch 4.44s -- TrainLoss 0.0105 -- ValLoss 0.0097 -- ValPSNR 20.1736
# [597/1852] -- Time: Data 0.40s, Epoch 4.38s -- TrainLoss 0.0103
# [598/1852] -- Time: Data 0.40s, Epoch 4.30s -- TrainLoss 0.0105 -- ValLoss 0.0098 -- ValPSNR 20.1819
# ...
# [1661/1852] -- Time: Data 0.39s, Epoch 4.28s -- TrainLoss 0.0099
# [1662/1852] -- Time: Data 0.39s, Epoch 4.33s -- TrainLoss 0.0098 -- ValLoss 0.0103 -- ValPSNR 19.8904
# [1663/1852] -- Time: Data 0.40s, Epoch 4.35s -- TrainLoss 0.0100
# [1664/1852] -- Time: Data 0.41s, Epoch 4.42s -- TrainLoss 0.0099 -- ValLoss 0.0104 -- ValPSNR 19.8776
# [1665/1852] -- Time: Data 0.45s, Epoch 4.37s -- TrainLoss 0.0099
# [1666/1852] -- Time: Data 0.39s, Epoch 4.42s -- TrainLoss 0.0098 -- ValLoss 0.0093 -- ValPSNR 20.5170
# [1667/1852] -- Time: Data 0.38s, Epoch 4.30s -- TrainLoss 0.0098
# [1668/1852] -- Time: Data 0.39s, Epoch 4.27s -- TrainLoss 0.0099 -- ValLoss 0.0110 -- ValPSNR 19.6726
# [1669/1852] -- Time: Data 0.37s, Epoch 4.35s -- TrainLoss 0.0099
# [1670/1852] -- Time: Data 0.40s, Epoch 4.31s -- TrainLoss 0.0099 -- ValLoss 0.0101 -- ValPSNR 19.9702
# [1671/1852] -- Time: Data 0.40s, Epoch 4.40s -- TrainLoss 0.0100
# [1672/1852] -- Time: Data 0.38s, Epoch 4.28s -- TrainLoss 0.0101 -- ValLoss 0.0101 -- ValPSNR 20.0161
# [1673/1852] -- Time: Data 0.41s, Epoch 4.31s -- TrainLoss 0.0099
# [1674/1852] -- Time: Data 0.37s, Epoch 4.25s -- TrainLoss 0.0099 -- ValLoss 0.0103 -- ValPSNR 19.9033
# [1675/1852] -- Time: Data 0.39s, Epoch 4.30s -- TrainLoss 0.0103
# [1676/1852] -- Time: Data 0.40s, Epoch 4.30s -- TrainLoss 0.0097 -- ValLoss 0.0100 -- ValPSNR 20.0135
# [1677/1852] -- Time: Data 0.44s, Epoch 4.33s -- TrainLoss 0.0098
# [1678/1852] -- Time: Data 0.37s, Epoch 4.30s -- TrainLoss 0.0103 -- ValLoss 0.0105 -- ValPSNR 19.8305
# [1679/1852] -- Time: Data 0.38s, Epoch 4.28s -- TrainLoss 0.0097
# [1680/1852] -- Time: Data 0.39s, Epoch 4.28s -- TrainLoss 0.0100 -- ValLoss 0.0098 -- ValPSNR 20.1090
# [1681/1852] -- Time: Data 0.39s, Epoch 4.30s -- TrainLoss 0.0099
# [1682/1852] -- Time: Data 0.37s, Epoch 4.27s -- TrainLoss 0.0101 -- ValLoss 0.0105 -- ValPSNR 19.7974
# [1683/1852] -- Time: Data 0.43s, Epoch 4.33s -- TrainLoss 0.0099
# [1684/1852] -- Time: Data 0.41s, Epoch 4.36s -- TrainLoss 0.0098 -- ValLoss 0.0102 -- ValPSNR 19.9207
# [1685/1852] -- Time: Data 0.40s, Epoch 4.35s -- TrainLoss 0.0098
# [1686/1852] -- Time: Data 0.40s, Epoch 4.30s -- TrainLoss 0.0098 -- ValLoss 0.0095 -- ValPSNR 20.2873
# [1687/1852] -- Time: Data 0.44s, Epoch 4.44s -- TrainLoss 0.0101
# [1688/1852] -- Time: Data 0.40s, Epoch 4.36s -- TrainLoss 0.0098 -- ValLoss 0.0096 -- ValPSNR 20.2191
# [1689/1852] -- Time: Data 0.41s, Epoch 4.44s -- TrainLoss 0.0099
# [1690/1852] -- Time: Data 0.38s, Epoch 4.31s -- TrainLoss 0.0101 -- ValLoss 0.0096 -- ValPSNR 20.3724
# [1691/1852] -- Time: Data 0.42s, Epoch 4.34s -- TrainLoss 0.0100
# [1692/1852] -- Time: Data 0.38s, Epoch 4.36s -- TrainLoss 0.0098 -- ValLoss 0.0105 -- ValPSNR 19.8455
# [1693/1852] -- Time: Data 0.39s, Epoch 4.33s -- TrainLoss 0.0099
# [1694/1852] -- Time: Data 0.43s, Epoch 4.43s -- TrainLoss 0.0099 -- ValLoss 0.0103 -- ValPSNR 19.8723
# [1695/1852] -- Time: Data 0.39s, Epoch 4.29s -- TrainLoss 0.0099
# [1696/1852] -- Time: Data 0.39s, Epoch 4.34s -- TrainLoss 0.0098 -- ValLoss 0.0106 -- ValPSNR 19.8132
# [1697/1852] -- Time: Data 0.41s, Epoch 4.35s -- TrainLoss 0.0098
# [1698/1852] -- Time: Data 0.41s, Epoch 4.36s -- TrainLoss 0.0099 -- ValLoss 0.0095 -- ValPSNR 20.2838
# [1699/1852] -- Time: Data 0.38s, Epoch 4.37s -- TrainLoss 0.0098
# [1700/1852] -- Time: Data 0.38s, Epoch 4.32s -- TrainLoss 0.0098 -- ValLoss 0.0115 -- ValPSNR 19.5909
# [1701/1852] -- Time: Data 0.40s, Epoch 4.31s -- TrainLoss 0.0098
# [1702/1852] -- Time: Data 0.39s, Epoch 4.31s -- TrainLoss 0.0098 -- ValLoss 0.0104 -- ValPSNR 19.8397
# [1703/1852] -- Time: Data 0.41s, Epoch 4.33s -- TrainLoss 0.0099
# [1704/1852] -- Time: Data 0.42s, Epoch 4.55s -- TrainLoss 0.0097 -- ValLoss 0.0107 -- ValPSNR 19.7708
# [1705/1852] -- Time: Data 0.38s, Epoch 4.29s -- TrainLoss 0.0102
# [1706/1852] -- Time: Data 0.40s, Epoch 4.32s -- TrainLoss 0.0098 -- ValLoss 0.0105 -- ValPSNR 19.7995
# [1707/1852] -- Time: Data 0.43s, Epoch 4.40s -- TrainLoss 0.0101
# [1708/1852] -- Time: Data 0.37s, Epoch 4.27s -- TrainLoss 0.0100 -- ValLoss 0.0104 -- ValPSNR 19.8871
# [1709/1852] -- Time: Data 0.39s, Epoch 4.30s -- TrainLoss 0.0100
# [1710/1852] -- Time: Data 0.43s, Epoch 4.36s -- TrainLoss 0.0100 -- ValLoss 0.0107 -- ValPSNR 19.7448
# [1711/1852] -- Time: Data 0.41s, Epoch 4.37s -- TrainLoss 0.0099
# [1712/1852] -- Time: Data 0.39s, Epoch 4.35s -- TrainLoss 0.0099 -- ValLoss 0.0094 -- ValPSNR 20.4036
# [1713/1852] -- Time: Data 0.41s, Epoch 4.49s -- TrainLoss 0.0098
# [1714/1852] -- Time: Data 0.40s, Epoch 4.31s -- TrainLoss 0.0099 -- ValLoss 0.0098 -- ValPSNR 20.0913
# [1715/1852] -- Time: Data 0.43s, Epoch 4.33s -- TrainLoss 0.0099
# [1716/1852] -- Time: Data 0.40s, Epoch 4.29s -- TrainLoss 0.0099 -- ValLoss 0.0093 -- ValPSNR 20.4862
# [1717/1852] -- Time: Data 0.41s, Epoch 4.32s -- TrainLoss 0.0099
# [1718/1852] -- Time: Data 0.40s, Epoch 4.34s -- TrainLoss 0.0099 -- ValLoss 0.0096 -- ValPSNR 20.2399
# [1719/1852] -- Time: Data 0.43s, Epoch 4.39s -- TrainLoss 0.0101
# [1720/1852] -- Time: Data 0.40s, Epoch 4.43s -- TrainLoss 0.0101 -- ValLoss 0.0097 -- ValPSNR 20.2341
# [1721/1852] -- Time: Data 0.43s, Epoch 4.33s -- TrainLoss 0.0099
# [1722/1852] -- Time: Data 0.37s, Epoch 4.28s -- TrainLoss 0.0098 -- ValLoss 0.0096 -- ValPSNR 20.2152
# [1723/1852] -- Time: Data 0.39s, Epoch 4.30s -- TrainLoss 0.0100
# [1724/1852] -- Time: Data 0.39s, Epoch 4.33s -- TrainLoss 0.0098 -- ValLoss 0.0102 -- ValPSNR 19.9616
# [1725/1852] -- Time: Data 0.37s, Epoch 4.35s -- TrainLoss 0.0099
# [1726/1852] -- Time: Data 0.40s, Epoch 4.29s -- TrainLoss 0.0100 -- ValLoss 0.0095 -- ValPSNR 20.3145
# [1727/1852] -- Time: Data 0.39s, Epoch 4.30s -- TrainLoss 0.0100
# [1728/1852] -- Time: Data 0.38s, Epoch 4.50s -- TrainLoss 0.0101 -- ValLoss 0.0098 -- ValPSNR 20.1249
# [1729/1852] -- Time: Data 0.37s, Epoch 4.31s -- TrainLoss 0.0099
# [1730/1852] -- Time: Data 0.42s, Epoch 4.36s -- TrainLoss 0.0098 -- ValLoss 0.0107 -- ValPSNR 19.7681
# [1731/1852] -- Time: Data 0.37s, Epoch 4.32s -- TrainLoss 0.0101
# [1732/1852] -- Time: Data 0.39s, Epoch 4.34s -- TrainLoss 0.0100 -- ValLoss 0.0112 -- ValPSNR 19.6445
# [1733/1852] -- Time: Data 0.46s, Epoch 4.37s -- TrainLoss 0.0099
# [1734/1852] -- Time: Data 0.43s, Epoch 4.34s -- TrainLoss 0.0100 -- ValLoss 0.0097 -- ValPSNR 20.2243
# [1735/1852] -- Time: Data 0.38s, Epoch 4.29s -- TrainLoss 0.0102
# [1736/1852] -- Time: Data 0.40s, Epoch 4.33s -- TrainLoss 0.0099 -- ValLoss 0.0094 -- ValPSNR 20.4439
# [1737/1852] -- Time: Data 0.42s, Epoch 4.32s -- TrainLoss 0.0099
# [1738/1852] -- Time: Data 0.40s, Epoch 4.34s -- TrainLoss 0.0100 -- ValLoss 0.0104 -- ValPSNR 19.8779
# [1739/1852] -- Time: Data 0.39s, Epoch 4.31s -- TrainLoss 0.0098
# [1740/1852] -- Time: Data 0.39s, Epoch 4.43s -- TrainLoss 0.0098 -- ValLoss 0.0099 -- ValPSNR 20.0922
# [1741/1852] -- Time: Data 0.41s, Epoch 4.31s -- TrainLoss 0.0099
# [1742/1852] -- Time: Data 0.39s, Epoch 4.53s -- TrainLoss 0.0099 -- ValLoss 0.0104 -- ValPSNR 19.9001
# [1743/1852] -- Time: Data 0.44s, Epoch 4.33s -- TrainLoss 0.0100
# [1744/1852] -- Time: Data 0.39s, Epoch 4.30s -- TrainLoss 0.0101 -- ValLoss 0.0103 -- ValPSNR 19.8747
# [1745/1852] -- Time: Data 0.38s, Epoch 4.28s -- TrainLoss 0.0101
# [1746/1852] -- Time: Data 0.40s, Epoch 4.47s -- TrainLoss 0.0100 -- ValLoss 0.0102 -- ValPSNR 19.9390
# [1747/1852] -- Time: Data 0.39s, Epoch 4.30s -- TrainLoss 0.0101
# [1748/1852] -- Time: Data 0.37s, Epoch 4.36s -- TrainLoss 0.0100 -- ValLoss 0.0109 -- ValPSNR 19.7272
# [1749/1852] -- Time: Data 0.39s, Epoch 4.32s -- TrainLoss 0.0098
# [1750/1852] -- Time: Data 0.38s, Epoch 4.28s -- TrainLoss 0.0101 -- ValLoss 0.0095 -- ValPSNR 20.3278
# [1751/1852] -- Time: Data 0.37s, Epoch 4.28s -- TrainLoss 0.0098
# [1752/1852] -- Time: Data 0.38s, Epoch 4.30s -- TrainLoss 0.0101 -- ValLoss 0.0101 -- ValPSNR 19.9785
# [1753/1852] -- Time: Data 0.42s, Epoch 4.49s -- TrainLoss 0.0099
# [1754/1852] -- Time: Data 0.39s, Epoch 4.35s -- TrainLoss 0.0099 -- ValLoss 0.0103 -- ValPSNR 19.8960
# [1755/1852] -- Time: Data 0.39s, Epoch 4.32s -- TrainLoss 0.0098
# [1756/1852] -- Time: Data 0.37s, Epoch 4.41s -- TrainLoss 0.0097 -- ValLoss 0.0099 -- ValPSNR 20.0881
# [1757/1852] -- Time: Data 0.39s, Epoch 4.28s -- TrainLoss 0.0099
# [1758/1852] -- Time: Data 0.38s, Epoch 4.28s -- TrainLoss 0.0100 -- ValLoss 0.0095 -- ValPSNR 20.3143
# [1759/1852] -- Time: Data 0.39s, Epoch 4.40s -- TrainLoss 0.0098
# [1760/1852] -- Time: Data 0.37s, Epoch 4.31s -- TrainLoss 0.0100 -- ValLoss 0.0096 -- ValPSNR 20.2023
# [1761/1852] -- Time: Data 0.43s, Epoch 4.33s -- TrainLoss 0.0100
# [1762/1852] -- Time: Data 0.37s, Epoch 4.30s -- TrainLoss 0.0097 -- ValLoss 0.0103 -- ValPSNR 19.9013
# [1763/1852] -- Time: Data 0.43s, Epoch 4.35s -- TrainLoss 0.0101
# [1764/1852] -- Time: Data 0.39s, Epoch 4.34s -- TrainLoss 0.0098 -- ValLoss 0.0093 -- ValPSNR 20.4841
# [1765/1852] -- Time: Data 0.40s, Epoch 4.34s -- TrainLoss 0.0101
# [1766/1852] -- Time: Data 0.42s, Epoch 4.34s -- TrainLoss 0.0099 -- ValLoss 0.0100 -- ValPSNR 20.0336
# [1767/1852] -- Time: Data 0.40s, Epoch 4.31s -- TrainLoss 0.0097
# [1768/1852] -- Time: Data 0.40s, Epoch 4.33s -- TrainLoss 0.0098 -- ValLoss 0.0105 -- ValPSNR 19.8008
# [1769/1852] -- Time: Data 0.39s, Epoch 4.29s -- TrainLoss 0.0098
# [1770/1852] -- Time: Data 0.44s, Epoch 4.35s -- TrainLoss 0.0100 -- ValLoss 0.0101 -- ValPSNR 20.0034
# [1771/1852] -- Time: Data 0.37s, Epoch 4.27s -- TrainLoss 0.0100
# [1772/1852] -- Time: Data 0.40s, Epoch 4.46s -- TrainLoss 0.0096 -- ValLoss 0.0111 -- ValPSNR 19.6493
# [1773/1852] -- Time: Data 0.44s, Epoch 4.35s -- TrainLoss 0.0099
# [1774/1852] -- Time: Data 0.39s, Epoch 4.35s -- TrainLoss 0.0102 -- ValLoss 0.0102 -- ValPSNR 19.9195
# [1775/1852] -- Time: Data 0.39s, Epoch 4.31s -- TrainLoss 0.0100
# [1776/1852] -- Time: Data 0.40s, Epoch 4.35s -- TrainLoss 0.0100 -- ValLoss 0.0100 -- ValPSNR 20.0287
# [1777/1852] -- Time: Data 0.40s, Epoch 4.51s -- TrainLoss 0.0101
# [1778/1852] -- Time: Data 0.38s, Epoch 4.31s -- TrainLoss 0.0099 -- ValLoss 0.0097 -- ValPSNR 20.1669
# [1779/1852] -- Time: Data 0.43s, Epoch 4.33s -- TrainLoss 0.0102
# [1780/1852] -- Time: Data 0.40s, Epoch 4.50s -- TrainLoss 0.0099 -- ValLoss 0.0105 -- ValPSNR 19.8260
# [1781/1852] -- Time: Data 0.40s, Epoch 4.31s -- TrainLoss 0.0101
# [1782/1852] -- Time: Data 0.40s, Epoch 4.29s -- TrainLoss 0.0098 -- ValLoss 0.0093 -- ValPSNR 20.5277
# [1783/1852] -- Time: Data 0.39s, Epoch 4.33s -- TrainLoss 0.0101
# [1784/1852] -- Time: Data 0.37s, Epoch 4.26s -- TrainLoss 0.0098 -- ValLoss 0.0104 -- ValPSNR 19.8633
# [1785/1852] -- Time: Data 0.41s, Epoch 4.31s -- TrainLoss 0.0100
# [1786/1852] -- Time: Data 0.39s, Epoch 4.48s -- TrainLoss 0.0101 -- ValLoss 0.0099 -- ValPSNR 20.0610
# [1787/1852] -- Time: Data 0.38s, Epoch 4.40s -- TrainLoss 0.0097
# [1788/1852] -- Time: Data 0.38s, Epoch 4.30s -- TrainLoss 0.0101 -- ValLoss 0.0103 -- ValPSNR 19.9000
# [1789/1852] -- Time: Data 0.38s, Epoch 4.29s -- TrainLoss 0.0102
# [1790/1852] -- Time: Data 0.38s, Epoch 4.29s -- TrainLoss 0.0098 -- ValLoss 0.0103 -- ValPSNR 19.8987
# [1791/1852] -- Time: Data 0.38s, Epoch 4.29s -- TrainLoss 0.0100
# [1792/1852] -- Time: Data 0.40s, Epoch 4.31s -- TrainLoss 0.0099 -- ValLoss 0.0106 -- ValPSNR 19.7953
# [1793/1852] -- Time: Data 0.43s, Epoch 4.35s -- TrainLoss 0.0097
# [1794/1852] -- Time: Data 0.40s, Epoch 4.28s -- TrainLoss 0.0099 -- ValLoss 0.0108 -- ValPSNR 19.8246
# [1795/1852] -- Time: Data 0.45s, Epoch 4.34s -- TrainLoss 0.0098
# [1796/1852] -- Time: Data 0.41s, Epoch 4.44s -- TrainLoss 0.0099 -- ValLoss 0.0112 -- ValPSNR 19.6644
# [1797/1852] -- Time: Data 0.39s, Epoch 4.30s -- TrainLoss 0.0102
# [1798/1852] -- Time: Data 0.40s, Epoch 4.30s -- TrainLoss 0.0100 -- ValLoss 0.0110 -- ValPSNR 19.6894
# [1799/1852] -- Time: Data 0.38s, Epoch 4.29s -- TrainLoss 0.0099
# [1800/1852] -- Time: Data 0.38s, Epoch 4.28s -- TrainLoss 0.0097 -- ValLoss 0.0097 -- ValPSNR 20.1429
# [1801/1852] -- Time: Data 0.40s, Epoch 4.39s -- TrainLoss 0.0098
# [1802/1852] -- Time: Data 0.37s, Epoch 4.36s -- TrainLoss 0.0099 -- ValLoss 0.0096 -- ValPSNR 20.3187
# [1803/1852] -- Time: Data 0.43s, Epoch 4.35s -- TrainLoss 0.0100
# [1804/1852] -- Time: Data 0.39s, Epoch 4.40s -- TrainLoss 0.0099 -- ValLoss 0.0094 -- ValPSNR 20.3478
# [1805/1852] -- Time: Data 0.41s, Epoch 4.31s -- TrainLoss 0.0099
# [1806/1852] -- Time: Data 0.40s, Epoch 4.31s -- TrainLoss 0.0101 -- ValLoss 0.0097 -- ValPSNR 20.2406
# [1807/1852] -- Time: Data 0.48s, Epoch 4.59s -- TrainLoss 0.0100
# [1808/1852] -- Time: Data 0.40s, Epoch 4.44s -- TrainLoss 0.0098 -- ValLoss 0.0095 -- ValPSNR 20.3771
# [1809/1852] -- Time: Data 0.42s, Epoch 4.46s -- TrainLoss 0.0100
# [1810/1852] -- Time: Data 0.38s, Epoch 4.26s -- TrainLoss 0.0099 -- ValLoss 0.0097 -- ValPSNR 20.1790
# [1811/1852] -- Time: Data 0.43s, Epoch 4.36s -- TrainLoss 0.0098
# [1812/1852] -- Time: Data 0.38s, Epoch 4.28s -- TrainLoss 0.0099 -- ValLoss 0.0100 -- ValPSNR 20.0332
# [1813/1852] -- Time: Data 0.40s, Epoch 4.39s -- TrainLoss 0.0099
# [1814/1852] -- Time: Data 0.44s, Epoch 4.34s -- TrainLoss 0.0101 -- ValLoss 0.0093 -- ValPSNR 20.4953
# [1815/1852] -- Time: Data 0.40s, Epoch 4.31s -- TrainLoss 0.0098
# [1816/1852] -- Time: Data 0.39s, Epoch 4.29s -- TrainLoss 0.0100 -- ValLoss 0.0099 -- ValPSNR 20.0633
# [1817/1852] -- Time: Data 0.39s, Epoch 4.46s -- TrainLoss 0.0102
# [1818/1852] -- Time: Data 0.40s, Epoch 4.50s -- TrainLoss 0.0100 -- ValLoss 0.0096 -- ValPSNR 20.2626
# [1819/1852] -- Time: Data 0.39s, Epoch 4.30s -- TrainLoss 0.0098
# [1820/1852] -- Time: Data 0.36s, Epoch 4.25s -- TrainLoss 0.0097 -- ValLoss 0.0097 -- ValPSNR 20.1999
# [1821/1852] -- Time: Data 0.43s, Epoch 4.36s -- TrainLoss 0.0100
# [1822/1852] -- Time: Data 0.44s, Epoch 4.37s -- TrainLoss 0.0100 -- ValLoss 0.0100 -- ValPSNR 20.0033
# [1823/1852] -- Time: Data 0.42s, Epoch 4.34s -- TrainLoss 0.0099
# [1824/1852] -- Time: Data 0.43s, Epoch 4.45s -- TrainLoss 0.0100 -- ValLoss 0.0105 -- ValPSNR 19.8370
# [1825/1852] -- Time: Data 0.43s, Epoch 4.38s -- TrainLoss 0.0098
# [1826/1852] -- Time: Data 0.37s, Epoch 4.28s -- TrainLoss 0.0097 -- ValLoss 0.0112 -- ValPSNR 19.6253
# [1827/1852] -- Time: Data 0.39s, Epoch 4.29s -- TrainLoss 0.0098
# [1828/1852] -- Time: Data 0.38s, Epoch 4.32s -- TrainLoss 0.0100 -- ValLoss 0.0099 -- ValPSNR 20.0566
# [1829/1852] -- Time: Data 0.38s, Epoch 4.51s -- TrainLoss 0.0100
# [1830/1852] -- Time: Data 0.39s, Epoch 4.29s -- TrainLoss 0.0098 -- ValLoss 0.0094 -- ValPSNR 20.3477
# [1831/1852] -- Time: Data 0.42s, Epoch 4.35s -- TrainLoss 0.0099
# [1832/1852] -- Time: Data 0.41s, Epoch 4.33s -- TrainLoss 0.0098 -- ValLoss 0.0098 -- ValPSNR 20.1645
# [1833/1852] -- Time: Data 0.40s, Epoch 4.30s -- TrainLoss 0.0097
# [1834/1852] -- Time: Data 0.38s, Epoch 4.36s -- TrainLoss 0.0101 -- ValLoss 0.0100 -- ValPSNR 20.0332
# [1835/1852] -- Time: Data 0.38s, Epoch 4.28s -- TrainLoss 0.0101
# [1836/1852] -- Time: Data 0.40s, Epoch 4.31s -- TrainLoss 0.0099 -- ValLoss 0.0098 -- ValPSNR 20.1225
# [1837/1852] -- Time: Data 0.37s, Epoch 4.28s -- TrainLoss 0.0097
# [1838/1852] -- Time: Data 0.40s, Epoch 4.36s -- TrainLoss 0.0097 -- ValLoss 0.0109 -- ValPSNR 19.6944
# [1839/1852] -- Time: Data 0.38s, Epoch 4.29s -- TrainLoss 0.0099
# [1840/1852] -- Time: Data 0.40s, Epoch 4.30s -- TrainLoss 0.0099 -- ValLoss 0.0101 -- ValPSNR 19.9671
# [1841/1852] -- Time: Data 0.38s, Epoch 4.32s -- TrainLoss 0.0100
# [1842/1852] -- Time: Data 0.41s, Epoch 4.30s -- TrainLoss 0.0100 -- ValLoss 0.0094 -- ValPSNR 20.4564
# [1843/1852] -- Time: Data 0.39s, Epoch 4.52s -- TrainLoss 0.0099
# [1844/1852] -- Time: Data 0.38s, Epoch 4.27s -- TrainLoss 0.0098 -- ValLoss 0.0106 -- ValPSNR 19.7683
# [1845/1852] -- Time: Data 0.40s, Epoch 4.34s -- TrainLoss 0.0098
# [1846/1852] -- Time: Data 0.40s, Epoch 4.34s -- TrainLoss 0.0098 -- ValLoss 0.0097 -- ValPSNR 20.1550
# [1847/1852] -- Time: Data 0.42s, Epoch 4.40s -- TrainLoss 0.0100
# [1848/1852] -- Time: Data 0.40s, Epoch 4.34s -- TrainLoss 0.0099 -- ValLoss 0.0108 -- ValPSNR 19.7309
# [1849/1852] -- Time: Data 0.43s, Epoch 4.35s -- TrainLoss 0.0101
# [1850/1852] -- Time: Data 0.42s, Epoch 4.34s -- TrainLoss 0.0099 -- ValLoss 0.0105 -- ValPSNR 19.8485
# [1851/1852] -- Time: Data 0.42s, Epoch 4.33s -- TrainLoss 0.0098

# %%
#save results

import pandas as pd

torch.save(model.state_dict(),'weights/transfer.zip')

df=pd.DataFrame(*list(zip(*logs['train']))[::-1],columns=['train_loss'])
df=df.join(pd.DataFrame([(i[1],i[2]) for i in logs['val']],index=[i[0] for i in logs['val']],columns=['val_loss','val_psnr']))
df=df.rename_axis('epoch')
df.to_csv('log_transfer.csv')

# %%
#save results

import pandas as pd

torch.save(model.state_dict(),'weights/transfer.zip')

df=pd.DataFrame(*list(zip(*logs['train']))[::-1],columns=['train_loss'])
df=df.join(pd.DataFrame([(i[1],i[2]) for i in logs['val']],index=[i[0] for i in logs['val']],columns=['val_loss','val_psnr']))
df=df.rename_axis('epoch')
df.to_csv('log_transfer.csv')
